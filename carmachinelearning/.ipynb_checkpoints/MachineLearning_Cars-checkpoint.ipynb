# %% [markdown]
# # Exploration of Craiglist Used Cars Sale Prices

# %% [markdown]
# ## Used car price prediction with Machine Learning

# %% [markdown]
# ##### 1. Project background and aim

# %% [markdown]
# #### Craiglist is an internet marketplace for a variety of new and used items. It allows you to, for example, purchase and sell things that you no longer need or purchase an item that fit in your budget. One challenge that the craiglist car data set from Kaggle gives is determining the optimal car price based on the various features provided.
# #### The aim of this project is to propose a data-driven solution, by using machine learning to predict the car sale price.

# %% [markdown]
# #### 2. Data Description

# %% [markdown]
# #### For this project, the data set derives from Kaggle. Each row in the data set is a listing available for a used car on craiglist for various cities and states within the United States. The columns describe different characteristics for each car listing(features).
# #### Features for this project are the following:
# ##### Year: the year of the car
# ##### Manufacturer: the make of the vehicle (Toyota, Nissan,etc.)
# ##### Model: the name of a car project (Camry, SUV,etc.)
# ##### Condition: the current state of the car ranging from excellent, very good, good, fair, poor.
# ##### Cylinders: known to be the power unit of an engine where the gasoline is burned and turned into power. Cylinders range from 4, 6, and 8.
# ##### Fuel: a type of energy source that provides power to vehicles
# ##### Title Status: a document that consists of the legal owner of the vehicle (Yes/No)
# ##### Transmission: the part of the car the turns the engine's power into something the car can use
# ##### Drive: is the wheel of a motor vehicle that transmit force which causes the vehicle to move
# ##### Size: size of the listed car (compact,mid-size,full-size,etc.)
# ##### Type: the type of car (wagon, pickup,SUV,etc.)
# ##### Paint Color: color of the listed car
# ##### State: location in which the car is being sold
# ##### Odometer: the logarithmic measure of the distance traveled by the listed vehicle

# %% [markdown]
# #### Install required packages

# %%
# Loading libraries required and reading dataset into python
import pandas as pd
import re
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Hide Warnings
import warnings
warnings.filterwarnings('ignore')


# Modeling
from sklearn.linear_model import Lasso, LinearRegression
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, mean_squared_log_error
from sklearn.metrics import mean_squared_error as mae,r2_score
from sklearn import linear_model
import sklearn.model_selection as ms
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
from mlxtend.regressor import StackingCVRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn import tree

# %% [markdown]
# #### Cleaning and pre-processing

# %%
df = pd.read_csv('cleaned_cars.csv')
df = df.drop(columns = ['Unnamed: 0'],axis = 1)
print(f'The dataset contains {len(df)} car listings')
# Out:
# The dataset contains 19279 car listings

# %% [markdown]
# #### Using 15% of the dataset for modeling

# %%
data = df.sample(frac = 0.15)
print(f'The sample dataset contains {len(data)} car listings')
# Out:
# The sample dataset contains 2892 car listings

# %%
data.isna().sum()
print('The dataset contains no missing values.')
# Out:
# The dataset contains no missing values.

# %%
# Distribution of the target variable: price
data.price_log.hist()

# %%
data.describe()
# Out:
#               year    price_log  odometer_log
# count  2892.000000  2892.000000   2892.000000
# mean   2008.719571     9.060577     11.526422
# std       6.965537     0.761261      0.705517
# min    1961.000000     6.935370      7.021976
# 25%    2006.000000     8.516993     11.264592
# 50%    2010.000000     9.093132     11.673351
# 75%    2013.000000     9.615805     11.958167
# max    2020.000000    10.962146     16.118097

# %%
# Turn Categorical Features into dummy variables
data  = pd.get_dummies(data, drop_first=True)
data.columns
# Out:
# Index(['year', 'price_log', 'odometer_log', 'manufacturer_alfa-romeo', 'manufacturer_audi', 'manufacturer_bmw', 'manufacturer_buick', 'manufacturer_cadillac', 'manufacturer_chevrolet', 'manufacturer_chrysler',
#        ...
#        'state_sd', 'state_tn', 'state_tx', 'state_ut', 'state_va', 'state_vt', 'state_wa', 'state_wi', 'state_wv', 'state_wy'], dtype='object', length=1452)

# %%
def printErrors(Yt,predMod):
    """
    This function takes the following inputs:
    1. Yt = the trained predicted values
    2. predMod = the prediction from the fitted model
    It thens prints the errors for the model ie MAE, MSE, RMSLE
    """
    errors = abs(np.expm1(predMod) - np.expm1(Yt))
    print('Mean Absolute Error (MAE): $', round(np.mean(errors), 2))
    print('Mean Squared Error (MSE):', mean_squared_error(Yt, predMod))
    print('Root Mean Square Error (RMSE):', np.sqrt(mean_squared_error(Yt, predMod)))
    print('Root Mean Square Log Error (RMSLE):', np.sqrt(mean_squared_log_error(Yt, predMod)))
    mape = 100 * (errors / np.expm1(Yt))
    print('Mean Absolute Percent Error (MAPE):', round(np.mean(mape), 2), '%.')

# %%
def printMod(Xtr,Xte,Ytr, Yte, modSel, modName):
    """
    This function takes the following inputs:
    1. Xtr,Xte,Ytr,Yte = X train data set, X test data set, Y train array, Y test array
    2. modSel is the fitted model
    3. modName is the model name used for plotting i.e. Lasso, Random Forest
    It then creates a plot for test vs train predicted prices
    """
    y_train_eNet = modSel.predict(Xtr)
    y_test_eNet = modSel.predict(Xte)
    # Plot predictions
    plt.figure(figsize=(12,8))
    plt.scatter(np.expm1(y_train_eNet), np.expm1(Ytr), c='black', marker="o", s=15, label = "Training data")
    plt.scatter(np.expm1(y_test_eNet), np.expm1(Yte), c='orange', marker='o', s=15, label = "Test data")
    plt.title(modName + " Model Train vs Test", fontsize = 20)
    plt.xlabel("Predicted Prices", fontsize = 16)
    plt.ylabel("Actual Prices", fontsize = 16)
    plt.xlim(0, 80000)
    plt.ylim(0, 80000)
    plt.legend(loc = "upper left")
    plt.plot([0,80000], [0,80000 ], c = "grey")
    plt.show()

# %%
def rmse_stack(model):
    """
    Perform kfold cross validation on stack model
    k = 5
    """
    kf = KFold(n_splits = 5, shuffle=True, random_state=20).get_n_splits(X_train)
    rmse= np.sqrt(-cross_val_score(model, np.array(X_train), Y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %%
kfo = KFold(n_splits=5,shuffle = True, random_state = 28)

# %%
# Setting feature variables in x , target in y
x = data.loc[:,data.columns != 'price_log'].copy()
y = data['price_log'].reset_index(drop=True)
print('train', x.shape, 'y', y.shape)
# Out:
# train (2892, 1451) y (2892,)

# %% [markdown]
# #### Model Preparation

# %%
# Performing train test split to train the models
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size= 0.35,random_state = 123, shuffle = True)

# %%
# Regex correction incase a column name has any symbols like: ([],<,etc.)
regex = re.compile(r"\[|\]|<", re.IGNORECASE)

X_train.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in X_train.columns.values]

# %%
regex = re.compile(r"\[|\]|<", re.IGNORECASE)

X_test.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in X_test.columns.values]

# %%
print('train', X_test.shape, 'y', X_train.shape)
# Out:
# train (1013, 1451) y (1879, 1451)

# %%
# Scale Data to center around zero.
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns= X_train.columns)
X_test_scaled = pd.DataFrame(scaler.fit_transform(X_test), columns= X_test.columns)
X_train_scaled.head()
# Out:
#        year  odometer_log  manufacturer_alfa-romeo  manufacturer_audi  manufacturer_bmw  manufacturer_buick  manufacturer_cadillac  manufacturer_chevrolet  manufacturer_chrysler  manufacturer_dodge  manufacturer_fiat  manufacturer_ford  manufacturer_gmc  manufacturer_honda  manufacturer_hyundai  manufacturer_infiniti  manufacturer_jaguar  manufacturer_jeep  manufacturer_kia  manufacturer_lexus  manufacturer_lincoln  manufacturer_mazda  manufacturer_mercedes-benz  manufacturer_mercury  manufacturer_mini  manufacturer_mitsubishi  manufacturer_nissan  manufacturer_pontiac  manufacturer_porche  manufacturer_ram  manufacturer_rover  manufacturer_saturn  manufacturer_subaru  manufacturer_tesla  manufacturer_toyota  manufacturer_volkswagen  manufacturer_volvo  model_1 series  model_128i  model_128i convertible  model_150 reg cab  model_1500  model_1500 4x4  model_1500 4x4 crew cab  model_1500 5.2 4x4  model_1500 big horn  model_1500 crew cab  model_1500 crew cab 4x4  \
# 0 -0.077126      0.774840                -0.023076          -0.098347         -0.153038           -0.127377              -0.125203               -0.415823               -0.14367           -0.161911          -0.032642          -0.520051         -0.258858            -0.22948              7.850690              -0.076738            -0.046188          -0.224293         -0.125203           -0.103723             -0.083467           -0.103723                   -0.149355             -0.073147          -0.076738                 -0.06539            -0.238339             -0.116122            -0.023076         -0.210877           -0.056599            -0.083467            -0.149355           -0.032642            -0.293474                -0.154849           -0.092673       -0.032642   -0.032642                     0.0                0.0   -0.116122       -0.032642                -0.023076           -0.023076            -0.023076            -0.023076                      0.0
# 1  0.344151      0.806412                -0.023076          -0.098347         -0.153038           -0.127377              -0.125203                2.404869               -0.14367           -0.161911          -0.032642          -0.520051         -0.258858            -0.22948             -0.127377              -0.076738            -0.046188          -0.224293         -0.125203           -0.103723             -0.083467           -0.103723                   -0.149355             -0.073147          -0.076738                 -0.06539            -0.238339             -0.116122            -0.023076         -0.210877           -0.056599            -0.083467            -0.149355           -0.032642            -0.293474                -0.154849           -0.092673       -0.032642   -0.032642                     0.0                0.0   -0.116122       -0.032642                -0.023076           -0.023076            -0.023076            -0.023076                      0.0
# 2 -0.779253      0.540876                -0.023076          -0.098347         -0.153038           -0.127377              -0.125203               -0.415823               -0.14367           -0.161911          -0.032642          -0.520051         -0.258858            -0.22948             -0.127377              -0.076738            -0.046188          -0.224293         -0.125203           -0.103723             -0.083467           -0.103723                   -0.149355             -0.073147          -0.076738                 -0.06539             4.195707             -0.116122            -0.023076         -0.210877           -0.056599            -0.083467            -0.149355           -0.032642            -0.293474                -0.154849           -0.092673       -0.032642   -0.032642                     0.0                0.0   -0.116122       -0.032642                -0.023076           -0.023076            -0.023076            -0.023076                      0.0
# 2  -0.06115 -0.086641  -0.06539 -0.122992 -0.086641 -0.069375 -0.264661 -0.192291 -0.147482  5.927446 -0.208109 -0.069375 -0.131626 -0.076738 -0.167031 -0.232038 -0.032642 -0.167031 -0.113745 -0.118454 -0.205309 -0.051654 -0.051654
# 3  -0.06115 -0.086641  -0.06539 -0.122992 -0.086641 -0.069375 -0.264661 -0.192291 -0.147482 -0.168707 -0.208109 -0.069375 -0.131626 -0.076738 -0.167031 -0.232038 -0.032642 -0.167031 -0.113745 -0.118454 -0.205309 -0.051654 -0.051654
# 4  -0.06115 -0.086641  -0.06539 -0.122992 -0.086641 -0.069375 -0.264661 -0.192291 -0.147482  5.927446 -0.208109 -0.069375 -0.131626 -0.076738 -0.167031 -0.232038 -0.032642 -0.167031 -0.113745 -0.118454 -0.205309 -0.051654 -0.051654
#
# [5 rows x 1451 columns]

# %% [markdown]
# #### Lasso Model

# %%
lasMod = linear_model.Lasso(normalize= True)
lasMod = lasMod.set_params(random_state = 42)
lasMod.fit(X_train_scaled,y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000, normalize=True,
#       positive=False, precompute=False, random_state=42, selection='cyclic',
#       tol=0.0001, warm_start=False)

# %%
lasso_pred = lasMod.predict(X_test_scaled)
printErrors(y_test,lasso_pred)
# Out:
# Mean Absolute Error (MAE): $ 6311.26
# Mean Squared Error (MSE): 0.5778230652381522
# Root Mean Square Error (RMSE): 0.7601467392800894
# Root Mean Square Log Error (RMSLE): 0.07625078265160884
# Mean Absolute Percent Error (MAPE): 74.08 %.

# %%
lasMod.score(X_test_scaled,y_test)
# Out:
# -0.00041793341035489817

# %% [raw]
# The Mean Squared Error is very high. Time to do a grid search.

# %% [markdown]
# #### Lasso Model Grid Search

# %%
alphas = [0.00024869479793950395]
param_grid_lasso = {"max_iter": [20],
                     "alpha": alphas}

# %%
grid_search_lasso = ms.GridSearchCV(lasMod, param_grid_lasso, scoring= 'neg_mean_squared_error', 
                                    cv= kfo, n_jobs=-1, return_train_score = True)

# %time grid_search_lasso.fit(X_train_scaled, y_train)
# Out:
# Wall time: 1.99 s
# GridSearchCV(cv=KFold(n_splits=5, random_state=28, shuffle=True),
#              error_score=nan,
#              estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=1000, normalize=True, positive=False,
#                              precompute=False, random_state=42,
#                              selection='cyclic', tol=0.0001, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'alpha': [0.00024869479793950396], 'max_iter': [20]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
# Prediction using the tuned parameters
grid_lasso = grid_search_lasso.best_estimator_

# %%
#Prediction with tuned hyperparameters
grid_lasso_pred = grid_lasso.predict(X_test_scaled)
printErrors(y_test,grid_lasso_pred)
# Out:
# Mean Absolute Error (MAE): $ 3155.94
# Mean Squared Error (MSE): 0.20275119681428208
# Root Mean Square Error (RMSE): 0.45027902106836165
# Root Mean Square Log Error (RMSLE): 0.046654131501761315
# Mean Absolute Percent Error (MAPE): 34.76 %.

# %%
print("The train set R^2 is: %.5f" % grid_lasso.score(X_train_scaled, y_train))
print("The test set R^2 is is: %.5f" % grid_lasso.score(X_test_scaled, y_test))
# Out:
# The train set R^2 is: 0.82561
# The test set R^2 is is: 0.64897

# %%
printMod(X_train_scaled,X_test_scaled,y_train,y_test,grid_lasso,"Lasso")

# %%
coeff = pd.DataFrame({"feature":X_train_scaled.columns,"coeff":grid_lasso.coef_})
coeff = coeff.sort_values(by = 'coeff', ascending = False)

print(coeff[coeff.coeff!=0].shape)
mod_=coeff[coeff.coeff!=0]
mod_.head(5)
# Out:
# (293, 2)
#                         feature     coeff
# 0                          year  0.365880
# 1361      cylinders_8 cylinders  0.076553
# 1387                 type_truck  0.076207
# 558                  model_f100  0.069188
# 866   model_mustang convertible  0.063218

# %%
coefs_lasso  = []

for alpha in alphas:
        grid_lasso.set_params(alpha=alpha)
        grid_lasso.fit(X_train_scaled, y_train)  
        coefs_lasso.append(grid_lasso.coef_)

coefs_lasso = pd.DataFrame(coefs_lasso, index = alphas, columns = X_train_scaled.columns)

# %% [markdown]
# ###### Results

# %%
info = [['Lasso',mean_squared_error(y_test,lasso_pred),(lasMod.score(X_test_scaled,y_test))],
        ['Lasso Grid Search',mean_squared_error(y_test,grid_lasso_pred),grid_lasso.score(X_test_scaled, y_test)]]
lasso_info = pd.DataFrame(info, columns= ['Name','MSE','R2-Score']) 
lasso_info
# Out:
#                 Name       MSE  R2-Score
# 0              Lasso  0.577823 -0.000418
# 1  Lasso Grid Search  0.202751  0.648965

# %% [markdown]
# ##### Elastic Net Model

# %%
# Elastic Net
eNet = linear_model.ElasticNet(normalize=True)
eNet = eNet.set_params(random_state = 42)

#fit baseline elastic net model on Train df
eNet.fit(X_train_scaled,y_train)
# Out:
# ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=True, positive=False, precompute=False,
#            random_state=42, selection='cyclic', tol=0.0001, warm_start=False)

# %%
eNet_pred = eNet.predict(X_test_scaled)
printErrors(y_test,eNet_pred)
# Out:
# Mean Absolute Error (MAE): $ 6311.26
# Mean Squared Error (MSE): 0.5778230652381522
# Root Mean Square Error (RMSE): 0.7601467392800894
# Root Mean Square Log Error (RMSLE): 0.07625078265160884
# Mean Absolute Percent Error (MAPE): 74.08 %.

# %%
eNet.score(X_test_scaled,y_test)
# Out:
# -0.00041793341035489817

# %%
# Elastic Net Grid Search

# %%
param_grid_eNet = {"max_iter": [10],
                    "alpha": [0.0002486947979395039],
                    "l1_ratio": [0.9]}
grid_search_eNet = ms.GridSearchCV(eNet, param_grid_eNet, scoring= 'neg_mean_squared_error', 
                                   cv= kfo, n_jobs=-1, return_train_score = True)

# %time grid_search_eNet.fit(X_train_scaled, y_train)
# Out:
# Wall time: 462 ms
# GridSearchCV(cv=KFold(n_splits=5, random_state=28, shuffle=True),
#              error_score=nan,
#              estimator=ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True,
#                                   l1_ratio=0.5, max_iter=1000, normalize=True,
#                                   positive=False, precompute=False,
#                                   random_state=42, selection='cyclic',
#                                   tol=0.0001, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'alpha': [0.0002486947979395039], 'l1_ratio': [0.9],
#                          'max_iter': [10]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
# Prediction using the tuned parameters
grid_eNet = grid_search_eNet.best_estimator_
grid_eNet_pred = grid_eNet.predict(X_test_scaled)

# %%
printErrors(y_test,grid_eNet_pred)
# Out:
# Mean Absolute Error (MAE): $ 3194.7
# Mean Squared Error (MSE): 0.19869642243284108
# Root Mean Square Error (RMSE): 0.4457537688375064
# Root Mean Square Log Error (RMSLE): 0.046006771861453646
# Mean Absolute Percent Error (MAPE): 35.22 %.

# %%
printMod(X_train_scaled,X_test_scaled,y_train,y_test,grid_eNet,"Elastic Net")

# %% [markdown]
# ###### Results

# %%
info = [['Elastic Net',mean_squared_error(y_test,eNet_pred),(eNet.score(X_test_scaled,y_test))],
        ['Elastic Net Grid Search',mean_squared_error(y_test,grid_eNet_pred),grid_eNet.score(X_test_scaled, y_test)]]
eNet_info = pd.DataFrame(info, columns= ['Name','MSE','R2-Score']) 
eNet_info
# Out:
#                       Name       MSE  R2-Score
# 0              Elastic Net  0.577823 -0.000418
# 1  Elastic Net Grid Search  0.198696  0.655986

# %% [markdown]
# ##### XG Boost Model

# %%
#initialize xgboost
xgb = XGBRegressor()
xgb.set_params(random_state=22,objective='reg:squarederror')
xgb.fit(X_train_scaled, y_train)
print("Train R^2 is: %.5f" % xgb.score(X_train_scaled, y_train))
print("Test set R^2 is is: %.5f" % xgb.score(X_test_scaled, y_test))
# Out:
# Train R^2 is: 0.83068
# Test set R^2 is is: 0.74102

# %%
r =xgb.score(X_test_scaled, y_test)

# %%
xgb_pred = xgb.predict(X_test_scaled)
printErrors(y_test, xgb_pred)
# Out:
# Mean Absolute Error (MAE): $ 2781.93
# Mean Squared Error (MSE): 0.14958359120691989
# Root Mean Square Error (RMSE): 0.38676037957231335
# Root Mean Square Log Error (RMSLE): 0.039656677564257274
# Mean Absolute Percent Error (MAPE): 32.23 %.

# %% [markdown]
# ##### XG Boost Grid Search 1

# %%
xgb_param_grid ={'learning_rate': [0.05],
                 'max_depth': [3],
                 'min_child_weight': [4],
                 'n_estimators': [500]}

grid_search_xgb = ms.GridSearchCV(xgb, xgb_param_grid, scoring='neg_mean_squared_error', 
                                     cv= kfo, n_jobs=-1, return_train_score = True)

# %%
# %time grid_search_xgb.fit(X_train_scaled, y_train)
# Out:
# Wall time: 2min 8s
# GridSearchCV(cv=KFold(n_splits=5, random_state=28, shuffle=True),
#              error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:squarederror',
#                                     random_state=22, reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'learning_rate': [0.05], 'max_depth': [3],
#                          'min_child_weight': [4], 'n_estimators': [500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
grid_search_xgb.best_params_
# Out:
# {'learning_rate': 0.05,
#  'max_depth': 3,
#  'min_child_weight': 4,
#  'n_estimators': 500}

# %%
grid_xgb = grid_search_xgb.best_estimator_

# %%
print("The train set R^2 is: %.5f" % grid_xgb.score(X_train_scaled, y_train))
print("The test set R^2 is is: %.5f" % grid_xgb.score(X_test_scaled, y_test))
# Out:
# The train set R^2 is: 0.85257
# The test set R^2 is is: 0.75909

# %%
grid_xgb_pred = grid_xgb.predict(X_test_scaled)
printErrors(y_test, grid_xgb_pred)
# Out:
# Mean Absolute Error (MAE): $ 2598.35
# Mean Squared Error (MSE): 0.13914278993949863
# Root Mean Square Error (RMSE): 0.37301848471556825
# Root Mean Square Log Error (RMSLE): 0.03823185425808781
# Mean Absolute Percent Error (MAPE): 30.27 %.

# %% [markdown]
# ##### XG Boost Grid Search 2

# %%
xgb_param_grid1 ={'learning_rate': [0.05],
                 'max_depth': [3],
                 'min_child_weight': [4],
                 'n_estimators': [500],
                 'subsample': [0.7],
                 'colsample_bytree' : [0.7],
                 'objective':['reg:squarederror'],
                 'nthread':[-1],
                 'scale_pos_weight':[1],
                 'seed':[27],
                 'reg_alpha': [0.00006]}
                 

grid_search_xgb1 = ms.GridSearchCV(xgb, xgb_param_grid1, scoring='neg_mean_squared_error', 
                                     cv= kfo, n_jobs=-1, return_train_score = True)
# %time grid_search_xgb1.fit(X_train_scaled, y_train)
# Out:
# Wall time: 1min 37s
# GridSearchCV(cv=KFold(n_splits=5, random_state=28, shuffle=True),
#              error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective...
#              iid='deprecated', n_jobs=-1,
#              param_grid={'colsample_bytree': [0.7], 'learning_rate': [0.05],
#                          'max_depth': [3], 'min_child_weight': [4],
#                          'n_estimators': [500], 'nthread': [-1],
#                          'objective': ['reg:squarederror'],
#                          'reg_alpha': [6e-05], 'scale_pos_weight': [1],
#                          'seed': [27], 'subsample': [0.7]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
grid_search_xgb1.best_params_
# Out:
# {'colsample_bytree': 0.7,
#  'learning_rate': 0.05,
#  'max_depth': 3,
#  'min_child_weight': 4,
#  'n_estimators': 500,
#  'nthread': -1,
#  'objective': 'reg:squarederror',
#  'reg_alpha': 6e-05,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'subsample': 0.7}

# %%
grid_xgb1 = grid_search_xgb1.best_estimator_
print("The train set R^2 is: %.5f" % grid_xgb1.score(X_train_scaled, y_train))
print("The test set R^2 is is: %.5f" % grid_xgb1.score(X_test_scaled, y_test))
# Out:
# The train set R^2 is: 0.86422
# The test set R^2 is is: 0.76050

# %%
printMod(X_train_scaled,X_test_scaled, y_train,y_test,grid_xgb1,"XGBoost")

# %%
grid_xgb_pred1 = grid_xgb1.predict(X_test_scaled)

printErrors(y_test, grid_xgb_pred1)
# Out:
# Mean Absolute Error (MAE): $ 2582.51
# Mean Squared Error (MSE): 0.13833267761517976
# Root Mean Square Error (RMSE): 0.3719310119029869
# Root Mean Square Log Error (RMSLE): 0.038138712757540945
# Mean Absolute Percent Error (MAPE): 30.04 %.

# %% [markdown]
# #### Important Features

# %%
# Get numerical feature importances
importances_xgb = list(xgb.feature_importances_)

# List of tuples with variable and importance
feature_importances_xgb = [(feature, round(importance, 5)) for feature, importance in zip(X_train_scaled.columns, importances_xgb)]

# Sort the feature importances by most important first
xgb_feature_importances = sorted(feature_importances_xgb, key = lambda x: x[1], reverse = True )

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in xgb_feature_importances[:10]]
# Out:
# Variable: year                 Importance: 0.10763999819755554
# Variable: drive_fwd            Importance: 0.06061000004410744
# Variable: type_sedan           Importance: 0.05508999899029732
# Variable: cylinders_8 cylinders Importance: 0.05451999977231026
# Variable: type_truck           Importance: 0.05299999937415123
# Variable: odometer_log         Importance: 0.0528700016438961
# Variable: fuel_gas             Importance: 0.049720000475645065
# Variable: cylinders_4 cylinders Importance: 0.036010000854730606
# Variable: size_full-size       Importance: 0.031950000673532486
# Variable: condition_fair       Importance: 0.026270000264048576
# [None, None, None, None, None, None, None, None, None, None]

# %%
xgb_feature_importances_top20 = xgb_feature_importances[:20]
featureNames, featureScores = zip(*list(xgb_feature_importances_top20))
xgb_feature_importances_top20
# Out:
# [('year', 0.10764),
#  ('drive_fwd', 0.06061),
#  ('type_sedan', 0.05509),
#  ('cylinders_8 cylinders', 0.05452),
#  ('type_truck', 0.053),
#  ('odometer_log', 0.05287),
#  ('fuel_gas', 0.04972),
#  ('cylinders_4 cylinders', 0.03601),
#  ('size_full-size', 0.03195),
#  ('condition_fair', 0.02627),
#  ('condition_good', 0.02361),
#  ('state_nv', 0.02082),
#  ('model_benz c300', 0.01506),
#  ('drive_rwd', 0.01233),
#  ('manufacturer_toyota', 0.01114),
#  ('state_oh', 0.0111),
#  ('state_in', 0.01098),
#  ('model_durango', 0.01093),
#  ('state_nh', 0.01033),
#  ('state_ny', 0.01033)]

# %%
plt.barh(range(len(featureScores)), featureScores, tick_label=featureNames)
plt.gca().invert_yaxis()
plt.title('feature importance')
plt.ylabel('Features')
plt.xlabel('Importance Score')
plt.title('Feature Importances')
# Out:
# Text(0.5, 1.0, 'Feature Importances')

# %% [markdown]
# ##### XG Boost Grid Search with important features

# %%
xgb_params_tuned_model = grid_search_xgb.best_estimator_
xgb_feature_importance = 100.0 * (xgb_params_tuned_model.feature_importances_ / xgb_params_tuned_model.feature_importances_.max())
xgb_important_features = X_train_scaled.columns[xgb_feature_importance >= 0.02]
xgb_unimportant_features = X_train_scaled.columns[xgb_feature_importance < 0.02]

# %%
xgb_important_features
# Out:
# Index(['year', 'odometer_log', 'manufacturer_audi', 'manufacturer_cadillac', 'manufacturer_chevrolet', 'manufacturer_chrysler', 'manufacturer_dodge', 'manufacturer_ford', 'manufacturer_gmc', 'manufacturer_honda',
#        ...
#        'state_nj', 'state_nv', 'state_ny', 'state_oh', 'state_ok', 'state_pa', 'state_tx', 'state_va', 'state_wa', 'state_wi'], dtype='object', length=115)

# %%
X_train_xgbreduced = X_train_scaled.drop(xgb_unimportant_features, axis=1)
X_test_xgbreduced = X_test_scaled.drop(xgb_unimportant_features, axis=1)

# %%
# GridSearchCV for multiple hyperparameters:
xgb=XGBRegressor()

xgb_param_grid ={'learning_rate': [0.05, 0.1, 0.15],
             'max_depth': [3, 4, 5],
             'n_estimators': [500]}

xgb.set_params(random_state=42)

grid_search_xgb2 = ms.GridSearchCV(xgb, xgb_param_grid, scoring= 'neg_mean_squared_error',
                           cv= kfo, n_jobs = 7, return_train_score=True, verbose = 1)
grid_search_xgb2.fit(X_train_xgbreduced, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=7)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  45 out of  45 | elapsed:   48.0s finished
# [13:53:57] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv=KFold(n_splits=5, random_state=28, shuffle=True),
#              error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=42,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=7,
#              param_grid={'learning_rate': [0.05, 0.1, 0.15],
#                          'max_depth': [3, 4, 5], 'n_estimators': [500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=1)

# %%
grid_search_xgb2.best_params_
# Out:
# {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 500}

# %%
predictions_tuned_xgb2 = grid_search_xgb2.best_estimator_.predict(X_test_xgbreduced)

# %%
printErrors(y_test, predictions_tuned_xgb2)
# Out:
# Mean Absolute Error (MAE): $ 2599.81
# Mean Squared Error (MSE): 0.14334936454631741
# Root Mean Square Error (RMSE): 0.37861506117205296
# Root Mean Square Log Error (RMSLE): 0.038866312557573404
# Mean Absolute Percent Error (MAPE): 30.63 %.

# %% [markdown]
# ###### Results

# %%
info = [['XGBoost',mean_squared_error(y_test,xgb_pred),xgb.score(X_test_scaled, y_test)],
        ['XGBoost Grid Search 1',mean_squared_error(y_test,grid_xgb_pred),grid_xgb.score(X_test_scaled, y_test)],
       ['XGBoost Grid Search 2', mean_squared_error(y_test, grid_xgb_pred1),grid_xgb1.score(X_test_scaled, y_test)],
       ['XG Boost Grid Search Impt.Feat', mean_squared_error(y_test,predictions_tuned_xgb2),grid_search_xgb2.score(X_test_xgbreduced,y_test)]]
xgb_info = pd.DataFrame(info, columns= ['Name','MSE','R2-Score']) 
xgb_info
# Out:
#                              Name       MSE  R2-Score
# 0                         XGBoost  0.149584  0.741017
# 1           XGBoost Grid Search 1  0.139143  0.759094
# 2           XGBoost Grid Search 2  0.138333  0.760497
# 3  XG Boost Grid Search Impt.Feat  0.143349 -0.143349

# %% [markdown]
# ##### Random Forest

# %%
#initialize RF model
#default n estimators = 10 will be deprecated and changed to 100 by default in new version .22, 
#set parameter n_estimators to 10
rforest = RandomForestRegressor()

rforest.set_params(random_state=52,n_estimators=10,)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=10, n_jobs=None, oob_score=False,
#                       random_state=52, verbose=0, warm_start=False)

# %%
#fit model on train data set
rforest.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=10, n_jobs=None, oob_score=False,
#                       random_state=52, verbose=0, warm_start=False)

# %%
#find R2 of model on train and test data sets
print("The train set R^2 is: %.5f" % rforest.score(X_train_scaled, y_train))
print("The test set R^2 is is: %.5f" % rforest.score(X_test_scaled, y_test))
# Out:
# The train set R^2 is: 0.95051
# The test set R^2 is is: 0.69613

# %%
rforest_pred = rforest.predict(X_test_scaled)

# %%
printErrors(y_test, rforest_pred)
# Out:
# Mean Absolute Error (MAE): $ 2847.59
# Mean Squared Error (MSE): 0.17551111981914228
# Root Mean Square Error (RMSE): 0.4189404728826546
# Root Mean Square Log Error (RMSLE): 0.04304003866674159
# Mean Absolute Percent Error (MAPE): 35.55 %.

# %% [markdown]
# ##### Random Forest Grid Search 1

# %%
# set parameter grid for kfold cross validation kfold is set above to 5
param_grid ={'max_depth': [20, 25, 30],
             'max_features': ['auto','sqrt','log2'],
             'min_samples_split':[2,3,4],
             'min_samples_leaf':[1, 3, 5],
             'n_estimators': [500]}

# %%
#test how different scoring impacts outcome...
grid_search_rforest = ms.GridSearchCV(rforest, param_grid, scoring='neg_mean_squared_error', 
                                     cv= kfo, n_jobs=-1, return_train_score = True)

# %%
# %time grid_search_rforest.fit(X_train_scaled, y_train)
# Out:
# Wall time: 12min 55s
# GridSearchCV(cv=KFold(n_splits=5, random_state=28, shuffle=True),
#              error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_es..._jobs=None,
#                                              oob_score=False, random_state=52,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'max_depth': [20, 25, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 3, 5],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
# get the best parameters
grid_search_rforest.best_params_
# Out:
# {'max_depth': 25,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 500}

# %%
# Prediction using the tuned parameters
grid_rforest = grid_search_rforest.best_estimator_

# %%
print("The train set R^2 is: %.5f" % grid_rforest.score(X_train_scaled, y_train))
print("The test set R^2 is is: %.5f" % grid_rforest.score(X_test_scaled, y_test))
# Out:
# The train set R^2 is: 0.96472
# The test set R^2 is is: 0.72570

# %%
#Prediction with tuned hyperparameters
grid_rforest_pred = grid_rforest.predict(X_test_scaled)

# %%
printErrors(y_test, grid_rforest_pred)
# Out:
# Mean Absolute Error (MAE): $ 2753.26
# Mean Squared Error (MSE): 0.15842965271383122
# Root Mean Square Error (RMSE): 0.3980322257227814
# Root Mean Square Log Error (RMSLE): 0.04089342605148253
# Mean Absolute Percent Error (MAPE): 33.48 %.

# %%
printMod(X_train_scaled,X_test_scaled,y_train,y_test,grid_rforest,"Random Forest")

# %% [markdown]
# #### Random Forest Feature Importance

# %%
# Get numerical feature importances
feats_rf = list(rforest.feature_importances_)

# List of tuples with variable and importance
feats_rf_score = [(feature, round(importance, 5)) for feature, importance in zip(X_train.columns, feats_rf)]

# Sort the feature importances by most important first
sorted_feats_rf_score = sorted(feats_rf_score, key = lambda x: x[1], reverse = True )

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in sorted_feats_rf_score]
# Out:
# Variable: year                 Importance: 0.42436
# Variable: odometer_log         Importance: 0.13374
# Variable: drive_fwd            Importance: 0.12693
# Variable: fuel_gas             Importance: 0.04298
# Variable: cylinders_8 cylinders Importance: 0.02892
# Variable: cylinders_4 cylinders Importance: 0.01797
# Variable: condition_fair       Importance: 0.00883
# Variable: condition_good       Importance: 0.00848
# Variable: type_truck           Importance: 0.00802
# Variable: type_sedan           Importance: 0.0072
# Variable: cylinders_6 cylinders Importance: 0.00694
# Variable: model_durango        Importance: 0.00473
# Variable: paint_color_white    Importance: 0.00441
# Variable: model_535i           Importance: 0.00419
# Variable: state_in             Importance: 0.00368
# Variable: size_mid-size        Importance: 0.00366
# Variable: transmission_manual  Importance: 0.00341
# Variable: drive_rwd            Importance: 0.00315
# Variable: state_nh             Importance: 0.00306
# Variable: manufacturer_ram     Importance: 0.00296
# Variable: manufacturer_cadillac Importance: 0.00291
# Variable: manufacturer_ford    Importance: 0.00285
# Variable: manufacturer_toyota  Importance: 0.00259
# Variable: state_ca             Importance: 0.00259
# Variable: type_pickup          Importance: 0.00251
# Variable: state_fl             Importance: 0.00246
# Variable: paint_color_silver   Importance: 0.00244
# Variable: state_oh             Importance: 0.00243
# Variable: title_status_rebuilt Importance: 0.0023
# Variable: model_200 limited    Importance: 0.0022
# Variable: size_full-size       Importance: 0.00218
# Variable: manufacturer_chevrolet Importance: 0.00208
# Variable: manufacturer_gmc     Importance: 0.00198
# Variable: model_f-150 xlt 4x4  Importance: 0.00191
# Variable: state_az             Importance: 0.00182
# Variable: model_ats            Importance: 0.00154
# Variable: model_nsx            Importance: 0.00153
# Variable: model_accord sedan   Importance: 0.0015
# Variable: condition_like new   Importance: 0.00147
# Variable: state_ia             Importance: 0.00142
# Variable: manufacturer_nissan  Importance: 0.0014
# Variable: paint_color_grey     Importance: 0.00139
# Variable: state_mn             Importance: 0.00138
# Variable: state_ny             Importance: 0.00135
# Variable: type_hatchback       Importance: 0.00132
# Variable: state_il             Importance: 0.00131
# Variable: model_rx 330         Importance: 0.00129
# Variable: state_nj             Importance: 0.00129
# Variable: state_ar             Importance: 0.00127
# Variable: state_tx             Importance: 0.00127
# Variable: model_cruze          Importance: 0.00125
# Variable: model_mkx            Importance: 0.00125
# Variable: model_grand marquis ls Importance: 0.00121
# Variable: model_escape         Importance: 0.00119
# Variable: model_tacoma double cab 4x4 Importance: 0.00112
# Variable: state_va             Importance: 0.00112
# Variable: manufacturer_lincoln Importance: 0.00111
# Variable: state_co             Importance: 0.00111
# Variable: model_jetta 2.5      Importance: 0.0011
# Variable: paint_color_yellow   Importance: 0.0011
# Variable: manufacturer_honda   Importance: 0.00106
# Variable: state_ok             Importance: 0.00105
# Variable: state_al             Importance: 0.00104
# Variable: paint_color_blue     Importance: 0.00102
# Variable: manufacturer_jeep    Importance: 0.00098
# Variable: model_prius hybrid   Importance: 0.00097
# Variable: paint_color_green    Importance: 0.00097
# Variable: model_sierra 1500    Importance: 0.00094
# Variable: model_suburban       Importance: 0.00094
# Variable: paint_color_red      Importance: 0.00094
# Variable: state_or             Importance: 0.00094
# Variable: model_wrangler       Importance: 0.00092
# Variable: state_sc             Importance: 0.00092
# Variable: state_ga             Importance: 0.00091
# Variable: type_coupe           Importance: 0.0009
# Variable: state_pa             Importance: 0.00088
# Variable: state_ma             Importance: 0.00086
# Variable: model_wrangler sport Importance: 0.00082
# Variable: state_tn             Importance: 0.00082
# Variable: model_tacoma         Importance: 0.00081
# Variable: title_status_salvage Importance: 0.00081
# Variable: type_van             Importance: 0.00081
# Variable: state_mi             Importance: 0.0008
# Variable: model_super duty f-550 drw Importance: 0.00079
# Variable: state_ks             Importance: 0.00079
# Variable: model_mustang convertible Importance: 0.00077
# Variable: size_sub-compact     Importance: 0.00073
# Variable: title_status_missing Importance: 0.0007
# Variable: manufacturer_lexus   Importance: 0.00069
# Variable: model_crown victoria police Importance: 0.00068
# Variable: manufacturer_mercury Importance: 0.00065
# Variable: model_excursion limited 4x4 Importance: 0.00064
# Variable: model_c4500          Importance: 0.00063
# Variable: state_wi             Importance: 0.00063
# Variable: model_f250 super duty Importance: 0.00062
# Variable: model_silverado 2500hd Importance: 0.00061
# Variable: state_nc             Importance: 0.00061
# Variable: type_wagon           Importance: 0.0006
# Variable: manufacturer_pontiac Importance: 0.00059
# Variable: manufacturer_buick   Importance: 0.00057
# Variable: manufacturer_dodge   Importance: 0.00057
# Variable: type_mini-van        Importance: 0.00057
# Variable: model_1500           Importance: 0.00055
# Variable: model_prius          Importance: 0.00055
# Variable: manufacturer_chrysler Importance: 0.00054
# Variable: model_ranger xlt     Importance: 0.00054
# Variable: model_f-250 super duty Importance: 0.00053
# Variable: state_ct             Importance: 0.00053
# Variable: model_f550           Importance: 0.00052
# Variable: model_impala         Importance: 0.00052
# Variable: paint_color_custom   Importance: 0.00052
# Variable: state_id             Importance: 0.00051
# Variable: model_f-150          Importance: 0.0005
# Variable: model_ranger super cab xlt Importance: 0.0005
# Variable: model_v3500          Importance: 0.0005
# Variable: model_350 super 4x4  Importance: 0.00049
# Variable: model_mkt            Importance: 0.00049
# Variable: model_expedition ltd 4x4 Importance: 0.00048
# Variable: model_fiesta         Importance: 0.00047
# Variable: state_mt             Importance: 0.00047
# Variable: model_f250 4wd       Importance: 0.00045
# Variable: model_sc1            Importance: 0.00045
# Variable: model_trax           Importance: 0.00045
# Variable: manufacturer_mazda   Importance: 0.00044
# Variable: manufacturer_volkswagen Importance: 0.00044
# Variable: model_element        Importance: 0.00044
# Variable: type_convertible     Importance: 0.00044
# Variable: paint_color_brown    Importance: 0.00044
# Variable: model_3500           Importance: 0.00043
# Variable: model_explorer       Importance: 0.00043
# Variable: manufacturer_kia     Importance: 0.00042
# Variable: model_wrangler unlimited Importance: 0.00042
# Variable: state_ri             Importance: 0.00042
# Variable: model_crown victoria interceptor Importance: 0.00041
# Variable: model_c4500 kodiak   Importance: 0.0004
# Variable: model_canyon crew cab Importance: 0.0004
# Variable: model_laramie 2500   Importance: 0.0004
# Variable: model_liberty sport 4x4 Importance: 0.00039
# Variable: model_navigator      Importance: 0.00039
# Variable: model_rio hb manual  Importance: 0.00039
# Variable: model_fj cruiser     Importance: 0.00038
# Variable: paint_color_orange   Importance: 0.00038
# Variable: manufacturer_subaru  Importance: 0.00037
# Variable: model_silverado      Importance: 0.00037
# Variable: model_f350 xlt       Importance: 0.00036
# Variable: model_odyssey ex-l   Importance: 0.00036
# Variable: model_town & country Importance: 0.00034
# Variable: manufacturer_saturn  Importance: 0.00033
# Variable: manufacturer_volvo   Importance: 0.00033
# Variable: model_f-150 stepside Importance: 0.00033
# Variable: model_grand am       Importance: 0.00033
# Variable: model_silverado 2500 Importance: 0.00033
# Variable: model_thunderbird coupe Importance: 0.00033
# Variable: state_nv             Importance: 0.00033
# Variable: model_lariat fx4     Importance: 0.00032
# Variable: manufacturer_infiniti Importance: 0.00029
# Variable: model_2500           Importance: 0.00029
# Variable: model_tl             Importance: 0.00029
# Variable: manufacturer_bmw     Importance: 0.00028
# Variable: model_focus          Importance: 0.00028
# Variable: state_nd             Importance: 0.00028
# Variable: state_vt             Importance: 0.00028
# Variable: model_civic si coupe Importance: 0.00026
# Variable: model_f150           Importance: 0.00026
# Variable: model_wrangler unlimited sahara Importance: 0.00026
# Variable: state_wa             Importance: 0.00026
# Variable: model_cherokee       Importance: 0.00025
# Variable: model_corvette grand sport Importance: 0.00025
# Variable: model_skylark        Importance: 0.00025
# Variable: model_1500 5.2 4x4   Importance: 0.00024
# Variable: model_e-450          Importance: 0.00024
# Variable: model_econoline      Importance: 0.00024
# Variable: model_f250 lariat crew cab 4x4 Importance: 0.00024
# Variable: cylinders_12 cylinders Importance: 0.00024
# Variable: model_grand marquis ls premium Importance: 0.00023
# Variable: state_me             Importance: 0.00023
# Variable: model_c7c042         Importance: 0.00022
# Variable: model_f350 xl sd 4x4 reg cab Importance: 0.00022
# Variable: model_s type         Importance: 0.00022
# Variable: model_unlimited conversion Importance: 0.00022
# Variable: state_ms             Importance: 0.00022
# Variable: manufacturer_jaguar  Importance: 0.00021
# Variable: model_1500 slt       Importance: 0.00021
# Variable: model_jimmy sle      Importance: 0.00021
# Variable: state_la             Importance: 0.00021
# Variable: manufacturer_mercedes-benz Importance: 0.0002
# Variable: model_g37 sedan      Importance: 0.0002
# Variable: model_liberty        Importance: 0.0002
# Variable: model_malibu         Importance: 0.0002
# Variable: state_nm             Importance: 0.0002
# Variable: model_300zx twin turbo Importance: 0.00019
# Variable: model_sonic lt sedan 4d Importance: 0.00019
# Variable: title_status_lien    Importance: 0.00019
# Variable: manufacturer_rover   Importance: 0.00018
# Variable: model_cr-v ex-l      Importance: 0.00018
# Variable: model_cts            Importance: 0.00018
# Variable: model_focus ses      Importance: 0.00018
# Variable: model_prius v        Importance: 0.00018
# Variable: model_tahoe lt       Importance: 0.00018
# Variable: model_4runner        Importance: 0.00017
# Variable: model_aveo 5         Importance: 0.00017
# Variable: model_civic lx       Importance: 0.00017
# Variable: model_f-250 superduty Importance: 0.00017
# Variable: model_k2500 hd       Importance: 0.00017
# Variable: model_super duty f-450 Importance: 0.00017
# Variable: state_mo             Importance: 0.00017
# Variable: state_sd             Importance: 0.00016
# Variable: model_continental    Importance: 0.00015
# Variable: model_equinox        Importance: 0.00015
# Variable: model_fiesta st manual Importance: 0.00015
# Variable: model_g6             Importance: 0.00015
# Variable: model_w4500          Importance: 0.00015
# Variable: fuel_hybrid          Importance: 0.00015
# Variable: state_dc             Importance: 0.00015
# Variable: state_ky             Importance: 0.00015
# Variable: manufacturer_hyundai Importance: 0.00014
# Variable: model_128i           Importance: 0.00014
# Variable: model_b2600i         Importance: 0.00014
# Variable: model_camry          Importance: 0.00014
# Variable: model_f350           Importance: 0.00014
# Variable: model_fusion se      Importance: 0.00014
# Variable: model_journey        Importance: 0.00014
# Variable: model_sierra         Importance: 0.00014
# Variable: model_silverado 2500hd 4x4 Importance: 0.00014
# Variable: model_accord         Importance: 0.00013
# Variable: model_charger r/t    Importance: 0.00013
# Variable: model_corvette       Importance: 0.00013
# Variable: model_express 1500   Importance: 0.00013
# Variable: model_f-250 sd       Importance: 0.00013
# Variable: model_highlander     Importance: 0.00013
# Variable: model_sebring convertible Importance: 0.00013
# Variable: model_sierra 3500hd  Importance: 0.00013
# Variable: model_tsx 2.4        Importance: 0.00013
# Variable: manufacturer_audi    Importance: 0.00012
# Variable: model_200            Importance: 0.00012
# Variable: model_escalade       Importance: 0.00012
# Variable: model_jetta 1.8t gli Importance: 0.00012
# Variable: model_lesabre        Importance: 0.00012
# Variable: model_maxima         Importance: 0.00012
# Variable: model_mustang coupe  Importance: 0.00012
# Variable: model_rx-8           Importance: 0.00012
# Variable: model_tacoma 4x4     Importance: 0.00012
# Variable: condition_new        Importance: 0.00012
# Variable: model_avalon limited Importance: 0.00011
# Variable: model_benz           Importance: 0.00011
# Variable: model_crown victoria lx Importance: 0.00011
# Variable: model_rabbit         Importance: 0.00011
# Variable: model_ranger         Importance: 0.00011
# Variable: model_rio            Importance: 0.00011
# Variable: model_silverado 1500 Importance: 0.00011
# Variable: model_silverado lt   Importance: 0.00011
# Variable: model_taurus         Importance: 0.00011
# Variable: model_tundra         Importance: 0.00011
# Variable: model_versa 1.8 s hatchback Importance: 0.00011
# Variable: paint_color_purple   Importance: 0.00011
# Variable: state_ne             Importance: 0.00011
# Variable: model_500            Importance: 0.0001
# Variable: model_rav4           Importance: 0.0001
# Variable: model_sienna         Importance: 0.0001
# Variable: model_sierra 3500    Importance: 0.0001
# Variable: model_torrent        Importance: 0.0001
# Variable: fuel_other           Importance: 0.0001
# Variable: type_offroad         Importance: 0.0001
# Variable: manufacturer_tesla   Importance: 9e-05
# Variable: model_explorer xlt 4x4 Importance: 9e-05
# Variable: model_f-150 fx4      Importance: 9e-05
# Variable: model_frontier       Importance: 9e-05
# Variable: model_grand cherokee Importance: 9e-05
# Variable: model_long wheel base Importance: 9e-05
# Variable: model_spark ls       Importance: 9e-05
# Variable: model_versa          Importance: 9e-05
# Variable: type_bus             Importance: 9e-05
# Variable: model_benz e55 amg   Importance: 8e-05
# Variable: model_c300           Importance: 8e-05
# Variable: model_f250           Importance: 8e-05
# Variable: model_focus se       Importance: 8e-05
# Variable: model_gs 300         Importance: 8e-05
# Variable: model_mdx            Importance: 8e-05
# Variable: model_pathfinder sv  Importance: 8e-05
# Variable: model_sequoia        Importance: 8e-05
# Variable: model_vue            Importance: 8e-05
# Variable: model_wrangler unlimited rubicon Importance: 8e-05
# Variable: model_xterra         Importance: 8e-05
# Variable: cylinders_3 cylinders Importance: 8e-05
# Variable: state_ut             Importance: 8e-05
# Variable: manufacturer_mini    Importance: 7e-05
# Variable: model_1500 laramie 4x4 Importance: 7e-05
# Variable: model_370z           Importance: 7e-05
# Variable: model_600 sedan      Importance: 7e-05
# Variable: model_accord ex (4cyl) Importance: 7e-05
# Variable: model_edge sel       Importance: 7e-05
# Variable: model_f-250          Importance: 7e-05
# Variable: model_f450           Importance: 7e-05
# Variable: model_juke           Importance: 7e-05
# Variable: model_monte carlo ss Importance: 7e-05
# Variable: model_blazer         Importance: 6e-05
# Variable: model_bronco         Importance: 6e-05
# Variable: model_caliber        Importance: 6e-05
# Variable: model_cherokee limited Importance: 6e-05
# Variable: model_dakota         Importance: 6e-05
# Variable: model_deville brougham Importance: 6e-05
# Variable: model_es 330         Importance: 6e-05
# Variable: model_expedition     Importance: 6e-05
# Variable: model_express 3500 extended Importance: 6e-05
# Variable: model_f-350 sd       Importance: 6e-05
# Variable: model_f250 xlt crew cab Importance: 6e-05
# Variable: model_f350 super duty Importance: 6e-05
# Variable: model_is250          Importance: 6e-05
# Variable: model_prelude        Importance: 6e-05
# Variable: model_suburban 1500  Importance: 6e-05
# Variable: model_tacoma 4 door 4wd Importance: 6e-05
# Variable: model_town and country Importance: 6e-05
# Variable: model_wangler        Importance: 6e-05
# Variable: model_300zx          Importance: 5e-05
# Variable: model_50             Importance: 5e-05
# Variable: model_a4             Importance: 5e-05
# Variable: model_camero rs      Importance: 5e-05
# Variable: model_equinox lt     Importance: 5e-05
# Variable: model_express 2500   Importance: 5e-05
# Variable: model_express 2500 cargo van Importance: 5e-05
# Variable: model_f-750          Importance: 5e-05
# Variable: model_f250 king ranch Importance: 5e-05
# Variable: model_forrester premium 2.5 Importance: 5e-05
# Variable: model_frontier se king cab Importance: 5e-05
# Variable: model_fusion         Importance: 5e-05
# Variable: model_grand cherokee limited Importance: 5e-05
# Variable: model_i3             Importance: 5e-05
# Variable: model_legacy         Importance: 5e-05
# Variable: model_mustang        Importance: 5e-05
# Variable: model_mustang coup   Importance: 5e-05
# Variable: model_passat         Importance: 5e-05
# Variable: model_ranger xlt 1999 Importance: 5e-05
# Variable: model_rav sport awd  Importance: 5e-05
# Variable: model_taurus limited Importance: 5e-05
# Variable: model_taurus se      Importance: 5e-05
# Variable: model_titan xd       Importance: 5e-05
# Variable: model_trailblazer    Importance: 5e-05
# Variable: model_traverse lt    Importance: 5e-05
# Variable: model_wrangler sport 4x4 Importance: 5e-05
# Variable: model_xc70           Importance: 5e-05
# Variable: model_yukon          Importance: 5e-05
# Variable: type_other           Importance: 5e-05
# Variable: manufacturer_mitsubishi Importance: 4e-05
# Variable: model_2500 passenger Importance: 4e-05
# Variable: model_2500 slt crew cummins Importance: 4e-05
# Variable: model_740il          Importance: 4e-05
# Variable: model_accord ex-l    Importance: 4e-05
# Variable: model_cruze ls       Importance: 4e-05
# Variable: model_elantra        Importance: 4e-05
# Variable: model_escape xlt     Importance: 4e-05
# Variable: model_f150 platinum 4x4 Importance: 4e-05
# Variable: model_f350 dually    Importance: 4e-05
# Variable: model_g35 coupe      Importance: 4e-05
# Variable: model_grand marquis  Importance: 4e-05
# Variable: model_lucerne        Importance: 4e-05
# Variable: model_promaster city Importance: 4e-05
# Variable: model_savanna cargo van Importance: 4e-05
# Variable: model_sebring        Importance: 4e-05
# Variable: model_sedona ex      Importance: 4e-05
# Variable: model_solstice       Importance: 4e-05
# Variable: model_sunfire        Importance: 4e-05
# Variable: model_vibe gt        Importance: 4e-05
# Variable: model_xc 70 awd      Importance: 4e-05
# Variable: state_md             Importance: 4e-05
# Variable: model_1500 quad cab 4x4 Importance: 3e-05
# Variable: model_328i convertible Importance: 3e-05
# Variable: model_accord lx      Importance: 3e-05
# Variable: model_avalanche ltz  Importance: 3e-05
# Variable: model_c230 kompressor Importance: 3e-05
# Variable: model_caravan        Importance: 3e-05
# Variable: model_corolla ce     Importance: 3e-05
# Variable: model_cruze lt       Importance: 3e-05
# Variable: model_e55 amg        Importance: 3e-05
# Variable: model_edge           Importance: 3e-05
# Variable: model_equinox ltz    Importance: 3e-05
# Variable: model_escalade esv   Importance: 3e-05
# Variable: model_explorer sport trac xlt Importance: 3e-05
# Variable: model_f-150 limited  Importance: 3e-05
# Variable: model_f-150 pu xcab 4w Importance: 3e-05
# Variable: model_f-350 dually   Importance: 3e-05
# Variable: model_f150 4x4       Importance: 3e-05
# Variable: model_f550 4x4       Importance: 3e-05
# Variable: model_fx35 awd       Importance: 3e-05
# Variable: model_highlander limited Importance: 3e-05
# Variable: model_ion            Importance: 3e-05
# Variable: model_jetta s        Importance: 3e-05
# Variable: model_malibu custom  Importance: 3e-05
# Variable: model_mustang gt coupe 2d Importance: 3e-05
# Variable: model_odyssey ex-l w/ dvd Importance: 3e-05
# Variable: model_pilot          Importance: 3e-05
# Variable: model_pilot ex-l 4x4 Importance: 3e-05
# Variable: model_rogue sl       Importance: 3e-05
# Variable: model_santa fe       Importance: 3e-05
# Variable: model_savana         Importance: 3e-05
# Variable: model_sentra se-r    Importance: 3e-05
# Variable: model_sierra 2500 hd Importance: 3e-05
# Variable: model_terrain        Importance: 3e-05
# Variable: model_titan          Importance: 3e-05
# Variable: model_x5             Importance: 3e-05
# Variable: model_yukon denali   Importance: 3e-05
# Variable: cylinders_5 cylinders Importance: 3e-05
# Variable: state_de             Importance: 3e-05
# Variable: model_1500 long bed truck Importance: 2e-05
# Variable: model_2500 4x4       Importance: 2e-05
# Variable: model_3 series       Importance: 2e-05
# Variable: model_300            Importance: 2e-05
# Variable: model_545i           Importance: 2e-05
# Variable: model_accent se      Importance: 2e-05
# Variable: model_accord ex      Importance: 2e-05
# Variable: model_altima 3.5 se  Importance: 2e-05
# Variable: model_astro          Importance: 2e-05
# Variable: model_avalanche 1500 Importance: 2e-05
# Variable: model_avalon xl      Importance: 2e-05
# Variable: model_avenger        Importance: 2e-05
# Variable: model_beetle         Importance: 2e-05
# Variable: model_benz s500      Importance: 2e-05
# Variable: model_benz sl500     Importance: 2e-05
# Variable: model_benz slk 350   Importance: 2e-05
# Variable: model_charger        Importance: 2e-05
# Variable: model_civic ex coupe 2d Importance: 2e-05
# Variable: model_cls 550        Importance: 2e-05
# Variable: model_cooper         Importance: 2e-05
# Variable: model_cooper clubman Importance: 2e-05
# Variable: model_cr-v 4x4       Importance: 2e-05
# Variable: model_dakota st extended cab rwd Importance: 2e-05
# Variable: model_dart sxt       Importance: 2e-05
# Variable: model_e-class        Importance: 2e-05
# Variable: model_e-series cargo e 150 Importance: 2e-05
# Variable: model_e350 cutaway   Importance: 2e-05
# Variable: model_electra        Importance: 2e-05
# Variable: model_entourage gls  Importance: 2e-05
# Variable: model_envoy denali 4wd Importance: 2e-05
# Variable: model_escape titanium Importance: 2e-05
# Variable: model_expedition eddie bauer Importance: 2e-05
# Variable: model_f-150 stx      Importance: 2e-05
# Variable: model_f150 lariat 4x4 Importance: 2e-05
# Variable: model_f150 xlt       Importance: 2e-05
# Variable: model_f250 super cab 4x4 Importance: 2e-05
# Variable: model_focus se sedan Importance: 2e-05
# Variable: model_freestyle sel  Importance: 2e-05
# Variable: model_fusion sel     Importance: 2e-05
# Variable: model_golf           Importance: 2e-05
# Variable: model_impala lt      Importance: 2e-05
# Variable: model_lacrosse cxl   Importance: 2e-05
# Variable: model_malibu ltz     Importance: 2e-05
# Variable: model_mkz            Importance: 2e-05
# Variable: model_ml350 4matic   Importance: 2e-05
# Variable: model_murano sl      Importance: 2e-05
# Variable: model_odyssey ex     Importance: 2e-05
# Variable: model_odyssey exl    Importance: 2e-05
# Variable: model_outback        Importance: 2e-05
# Variable: model_patriot sport  Importance: 2e-05
# Variable: model_powerwagon     Importance: 2e-05
# Variable: model_promaster 3500 high roof Importance: 2e-05
# Variable: model_r350 bluetec   Importance: 2e-05
# Variable: model_rendezvous cx  Importance: 2e-05
# Variable: model_rogue select s awd Importance: 2e-05
# Variable: model_sierra 1500 slt Importance: 2e-05
# Variable: model_sierra 2500hd  Importance: 2e-05
# Variable: model_sierra allterrain 4wd Importance: 2e-05
# Variable: model_silverado k1500 4wd Importance: 2e-05
# Variable: model_silverado ltz  Importance: 2e-05
# Variable: model_sorento ex     Importance: 2e-05
# Variable: model_sts            Importance: 2e-05
# Variable: model_suburban 1500 ltz Importance: 2e-05
# Variable: model_super duty f-250 srw Importance: 2e-05
# Variable: model_tahoe          Importance: 2e-05
# Variable: model_thunderbird lx Importance: 2e-05
# Variable: model_town car       Importance: 2e-05
# Variable: model_trailblazer ls Importance: 2e-05
# Variable: model_tsx🚘           Importance: 2e-05
# Variable: model_tundra sr5 double cab 4wd Importance: 2e-05
# Variable: model_yukon xl       Importance: 2e-05
# Variable: model_1500 laramie crew cab Importance: 1e-05
# Variable: model_3 series 335i convertible Importance: 1e-05
# Variable: model_300c           Importance: 1e-05
# Variable: model_328ci          Importance: 1e-05
# Variable: model_328i           Importance: 1e-05
# Variable: model_4runner awd    Importance: 1e-05
# Variable: model_500 pop        Importance: 1e-05
# Variable: model_90 quattro     Importance: 1e-05
# Variable: model_a5 2.0t quattro Importance: 1e-05
# Variable: model_acadia         Importance: 1e-05
# Variable: model_acadia slt     Importance: 1e-05
# Variable: model_allante convertible Importance: 1e-05
# Variable: model_altima         Importance: 1e-05
# Variable: model_altima 2.5 4dr sedan Importance: 1e-05
# Variable: model_altima 2.5 sl  Importance: 1e-05
# Variable: model_altima 2.5 sl! Importance: 1e-05
# Variable: model_armada         Importance: 1e-05
# Variable: model_armada le ffv  Importance: 1e-05
# Variable: model_aura xe        Importance: 1e-05
# Variable: model_avalanche      Importance: 1e-05
# Variable: model_avenger se     Importance: 1e-05
# Variable: model_avenger sxt    Importance: 1e-05
# Variable: model_benz c230      Importance: 1e-05
# Variable: model_benz c300      Importance: 1e-05
# Variable: model_camaro rs      Importance: 1e-05
# Variable: model_camaro ss      Importance: 1e-05
# Variable: model_century custom Importance: 1e-05
# Variable: model_charger pursuit Importance: 1e-05
# Variable: model_cheyenne       Importance: 1e-05
# Variable: model_civic touring sedan Importance: 1e-05
# Variable: model_cj5            Importance: 1e-05
# Variable: model_cls            Importance: 1e-05
# Variable: model_compass        Importance: 1e-05
# Variable: model_compass sport  Importance: 1e-05
# Variable: model_corolla le     Importance: 1e-05
# Variable: model_corolla s      Importance: 1e-05
# Variable: model_corvette convertible Importance: 1e-05
# Variable: model_crv            Importance: 1e-05
# Variable: model_crv ex-l       Importance: 1e-05
# Variable: model_crv exl awd suv Importance: 1e-05
# Variable: model_e350 box       Importance: 1e-05
# Variable: model_edge limited awd Importance: 1e-05
# Variable: model_enclave        Importance: 1e-05
# Variable: model_escape se      Importance: 1e-05
# Variable: model_explorer 4x4   Importance: 1e-05
# Variable: model_express        Importance: 1e-05
# Variable: model_express 3500 lt ext Importance: 1e-05
# Variable: model_f-550          Importance: 1e-05
# Variable: model_f150 king ranch Importance: 1e-05
# Variable: model_f150 xlt super crew cab Importance: 1e-05
# Variable: model_f250 lariat    Importance: 1e-05
# Variable: model_f250 super duty 4x4 Importance: 1e-05
# Variable: model_f350 superduty 4x4 Importance: 1e-05
# Variable: model_f350 xl 4x4 dump truck Importance: 1e-05
# Variable: model_five hundred sel Importance: 1e-05
# Variable: model_flex limited   Importance: 1e-05
# Variable: model_focus sel hatchback 4d Importance: 1e-05
# Variable: model_frontier 2wd   Importance: 1e-05
# Variable: model_frontier crew cab se Importance: 1e-05
# Variable: model_g30 van        Importance: 1e-05
# Variable: model_ge 400         Importance: 1e-05
# Variable: model_genesis coupe 3.8 r-spec Importance: 1e-05
# Variable: model_grand cherokee laredo Importance: 1e-05
# Variable: model_grand prix gt  Importance: 1e-05
# Variable: model_gs300          Importance: 1e-05
# Variable: model_highlander plus v6 Importance: 1e-05
# Variable: model_impreza wrx    Importance: 1e-05
# Variable: model_jetta          Importance: 1e-05
# Variable: model_jetta limited edition Importance: 1e-05
# Variable: model_land cruiser fj40 Importance: 1e-05
# Variable: model_lasabre custom Importance: 1e-05
# Variable: model_liberty jet edition Importance: 1e-05
# Variable: model_lr2 se         Importance: 1e-05
# Variable: model_mazda3 hatchback sport Importance: 1e-05
# Variable: model_mdx touring    Importance: 1e-05
# Variable: model_murano sl awd  Importance: 1e-05
# Variable: model_oddysey ex-l   Importance: 1e-05
# Variable: model_odyssey        Importance: 1e-05
# Variable: model_outlander sport Importance: 1e-05
# Variable: model_passat gls wagon Importance: 1e-05
# Variable: model_pathfinder le  Importance: 1e-05
# Variable: model_patriot        Importance: 1e-05
# Variable: model_pilot ex-l     Importance: 1e-05
# Variable: model_promaster 1500 high roof Importance: 1e-05
# Variable: model_protege sedan  Importance: 1e-05
# Variable: model_q3 premium plus Importance: 1e-05
# Variable: model_q5 3.0t premium plus Importance: 1e-05
# Variable: model_rav4 limited   Importance: 1e-05
# Variable: model_rav4 limited 3rd row Importance: 1e-05
# Variable: model_ridgeline      Importance: 1e-05
# Variable: model_rl             Importance: 1e-05
# Variable: model_rogue          Importance: 1e-05
# Variable: model_s550           Importance: 1e-05
# Variable: model_s60            Importance: 1e-05
# Variable: model_savana 2500    Importance: 1e-05
# Variable: model_sentra         Importance: 1e-05
# Variable: model_sentra sv      Importance: 1e-05
# Variable: model_sequoia limited Importance: 1e-05
# Variable: model_sienna ce 7 passenger Importance: 1e-05
# Variable: model_sienna xle limited awd Importance: 1e-05
# Variable: model_sierra 2500 hd 4x4 Importance: 1e-05
# Variable: model_silverado 1500 ls Importance: 1e-05
# Variable: model_silverado 1500 lt Importance: 1e-05
# Variable: model_silverdo z71   Importance: 1e-05
# Variable: model_sorento sx     Importance: 1e-05
# Variable: model_soul           Importance: 1e-05
# Variable: model_soul 1.6l      Importance: 1e-05
# Variable: model_suburban 1500 xl Importance: 1e-05
# Variable: model_super duty f-250 Importance: 1e-05
# Variable: model_super duty f-350 srw Importance: 1e-05
# Variable: model_super duty f-550 Importance: 1e-05
# Variable: model_terrain sle    Importance: 1e-05
# Variable: model_tiguan         Importance: 1e-05
# Variable: model_town and country tourin Importance: 1e-05
# Variable: model_town n country Importance: 1e-05
# Variable: model_trailblazer ls 4x4 Importance: 1e-05
# Variable: model_trailblazer lt Importance: 1e-05
# Variable: model_transit 250    Importance: 1e-05
# Variable: model_transit 250 work van Importance: 1e-05
# Variable: model_traverse       Importance: 1e-05
# Variable: model_tucson         Importance: 1e-05
# Variable: model_tundra double cab Importance: 1e-05
# Variable: model_tundra limited Importance: 1e-05
# Variable: model_venza le v6 awd Importance: 1e-05
# Variable: model_verano         Importance: 1e-05
# Variable: model_vibe           Importance: 1e-05
# Variable: model_wrangler freedom edition Importance: 1e-05
# Variable: model_xf             Importance: 1e-05
# Variable: model_xv crosstrek 2.0i limited Importance: 1e-05
# Variable: model_yaris          Importance: 1e-05
# Variable: model_yukon xl denali Importance: 1e-05
# Variable: manufacturer_alfa-romeo Importance: 0.0
# Variable: manufacturer_fiat    Importance: 0.0
# Variable: manufacturer_porche  Importance: 0.0
# Variable: model_1 series       Importance: 0.0
# Variable: model_128i convertible Importance: 0.0
# Variable: model_150 reg cab    Importance: 0.0
# Variable: model_1500 4x4       Importance: 0.0
# Variable: model_1500 4x4 crew cab Importance: 0.0
# Variable: model_1500 big horn  Importance: 0.0
# Variable: model_1500 crew cab  Importance: 0.0
# Variable: model_1500 crew cab 4x4 Importance: 0.0
# Variable: model_1500 crew cab big horn Importance: 0.0
# Variable: model_1500 crew cab v8 4x4 Importance: 0.0
# Variable: model_1500 laramie   Importance: 0.0
# Variable: model_1500 sierra    Importance: 0.0
# Variable: model_1500 silverado lt 4x4 Importance: 0.0
# Variable: model_1500 slt 4x4   Importance: 0.0
# Variable: model_1500 slt 4x4. 5.7 hemi Importance: 0.0
# Variable: model_1500 sport     Importance: 0.0
# Variable: model_1500 suburban  Importance: 0.0
# Variable: model_1500 tradesman 4x4 Importance: 0.0
# Variable: model_2              Importance: 0.0
# Variable: model_200 lx         Importance: 0.0
# Variable: model_200 s          Importance: 0.0
# Variable: model_200 touring    Importance: 0.0
# Variable: model_2500 4x4 long bed Importance: 0.0
# Variable: model_2500 cummins   Importance: 0.0
# Variable: model_2500 diesel    Importance: 0.0
# Variable: model_2500 hd        Importance: 0.0
# Variable: model_2500 hd crew cab Importance: 0.0
# Variable: model_2500 laramie   Importance: 0.0
# Variable: model_2500 silverado Importance: 0.0
# Variable: model_2500hd 4x4     Importance: 0.0
# Variable: model_3              Importance: 0.0
# Variable: model_3 i            Importance: 0.0
# Variable: model_3 i touring    Importance: 0.0
# Variable: model_3 sport touring Importance: 0.0
# Variable: model_3-series       Importance: 0.0
# Variable: model_3.2tl          Importance: 0.0
# Variable: model_300c hemi      Importance: 0.0
# Variable: model_300m           Importance: 0.0
# Variable: model_300zx 2+2      Importance: 0.0
# Variable: model_325i           Importance: 0.0
# Variable: model_325xi          Importance: 0.0
# Variable: model_325xi wagon    Importance: 0.0
# Variable: model_328 xdrive sport package Importance: 0.0
# Variable: model_328i sedan     Importance: 0.0
# Variable: model_330i           Importance: 0.0
# Variable: model_3500 cummins 4x4 Importance: 0.0
# Variable: model_3500 slt       Importance: 0.0
# Variable: model_3500 slt quad cab 4wd Importance: 0.0
# Variable: model_3500 srw 4x4 diesel st Importance: 0.0
# Variable: model_3500 tradesman dually Importance: 0.0
# Variable: model_370z nismo     Importance: 0.0
# Variable: model_428 i coupe    Importance: 0.0
# Variable: model_4500           Importance: 0.0
# Variable: model_4runner 4wd    Importance: 0.0
# Variable: model_4runner limited v8- 4wd Importance: 0.0
# Variable: model_4runner sr5    Importance: 0.0
# Variable: model_4runner sr5 4wd Importance: 0.0
# Variable: model_5              Importance: 0.0
# Variable: model_5 series 528i  Importance: 0.0
# Variable: model_5 touring      Importance: 0.0
# Variable: model_525i           Importance: 0.0
# Variable: model_528i xdrive    Importance: 0.0
# Variable: model_530i           Importance: 0.0
# Variable: model_530xi          Importance: 0.0
# Variable: model_535d m sport package Importance: 0.0
# Variable: model_535i xdrive    Importance: 0.0
# Variable: model_5500           Importance: 0.0
# Variable: model_550i           Importance: 0.0
# Variable: model_6              Importance: 0.0
# Variable: model_6 grand touring sedan 4d Importance: 0.0
# Variable: model_650i xdrive    Importance: 0.0
# Variable: model_8-series       Importance: 0.0
# Variable: model_a3 1.8t premium Importance: 0.0
# Variable: model_a4 2.0t        Importance: 0.0
# Variable: model_a4 2.0t avant quattro Importance: 0.0
# Variable: model_a4 2.0t premium plus Importance: 0.0
# Variable: model_a4 quattro     Importance: 0.0
# Variable: model_a5             Importance: 0.0
# Variable: model_a6             Importance: 0.0
# Variable: model_a6 quattro     Importance: 0.0
# Variable: model_a8             Importance: 0.0
# Variable: model_a8 l awd, 4dr, cars Importance: 0.0
# Variable: model_a8 quattro     Importance: 0.0
# Variable: model_acadia awd     Importance: 0.0
# Variable: model_acadia sle     Importance: 0.0
# Variable: model_acadia slt-1   Importance: 0.0
# Variable: model_acadia slt2    Importance: 0.0
# Variable: model_accent         Importance: 0.0
# Variable: model_accent gs      Importance: 0.0
# Variable: model_accord 4-door sedan Importance: 0.0
# Variable: model_accord coupe ex-l Importance: 0.0
# Variable: model_accord ex coupe Importance: 0.0
# Variable: model_accord lx-p    Importance: 0.0
# Variable: model_accord sport   Importance: 0.0
# Variable: model_altima 2.5 s   Importance: 0.0
# Variable: model_altima sl      Importance: 0.0
# Variable: model_armada le      Importance: 0.0
# Variable: model_armada se      Importance: 0.0
# Variable: model_aspen limited  Importance: 0.0
# Variable: model_astro van      Importance: 0.0
# Variable: model_ats 2.0l turbo premium Importance: 0.0
# Variable: model_avalanche 4wd  Importance: 0.0
# Variable: model_avalanche ls   Importance: 0.0
# Variable: model_avalanche ltz 4x4 Importance: 0.0
# Variable: model_avalanche z71  Importance: 0.0
# Variable: model_avalon         Importance: 0.0
# Variable: model_aviator        Importance: 0.0
# Variable: model_azera          Importance: 0.0
# Variable: model_b3000          Importance: 0.0
# Variable: model_b4000          Importance: 0.0
# Variable: model_b9 tribeca     Importance: 0.0
# Variable: model_benz c240 4matic Importance: 0.0
# Variable: model_benz c250      Importance: 0.0
# Variable: model_benz c280 4matic Importance: 0.0
# Variable: model_benz cls63 amg Importance: 0.0
# Variable: model_benz e320      Importance: 0.0
# Variable: model_benz e350 4matic Importance: 0.0
# Variable: model_benz e350 4matic sedan Importance: 0.0
# Variable: model_benz e63 amg   Importance: 0.0
# Variable: model_benz gl450     Importance: 0.0
# Variable: model_benz glk 350   Importance: 0.0
# Variable: model_benz ml350     Importance: 0.0
# Variable: model_benz s430 4matic Importance: 0.0
# Variable: model_benz slk       Importance: 0.0
# Variable: model_bonneville se  Importance: 0.0
# Variable: model_bronco 11 xlt  Importance: 0.0
# Variable: model_c-class        Importance: 0.0
# Variable: model_c-class 350    Importance: 0.0
# Variable: model_c-class c300   Importance: 0.0
# Variable: model_c1500          Importance: 0.0
# Variable: model_c240           Importance: 0.0
# Variable: model_c70 t5         Importance: 0.0
# Variable: model_c7500          Importance: 0.0
# Variable: model_c7e042         Importance: 0.0
# Variable: model_caballero      Importance: 0.0
# Variable: model_cabrio         Importance: 0.0
# Variable: model_caliber se     Importance: 0.0
# Variable: model_camaro         Importance: 0.0
# Variable: model_camaro lt      Importance: 0.0
# Variable: model_camaro ss coupe 2d Importance: 0.0
# Variable: model_camaro z28     Importance: 0.0
# Variable: model_camper bus     Importance: 0.0
# Variable: model_camry le       Importance: 0.0
# Variable: model_camry le 4dr sedan Importance: 0.0
# Variable: model_camry se       Importance: 0.0
# Variable: model_camry se 4dr sedan Importance: 0.0
# Variable: model_camry solara   Importance: 0.0
# Variable: model_camry solara convertible Importance: 0.0
# Variable: model_camry xle      Importance: 0.0
# Variable: model_canyon sle     Importance: 0.0
# Variable: model_caprice        Importance: 0.0
# Variable: model_caravan crew   Importance: 0.0
# Variable: model_caravan sport  Importance: 0.0
# Variable: model_cascada premium Importance: 0.0
# Variable: model_catera         Importance: 0.0
# Variable: model_cavalier       Importance: 0.0
# Variable: model_cavalier ls    Importance: 0.0
# Variable: model_cayenne turbo awd Importance: 0.0
# Variable: model_cc lux         Importance: 0.0
# Variable: model_cc sport       Importance: 0.0
# Variable: model_celica gt-s    Importance: 0.0
# Variable: model_century sedan  Importance: 0.0
# Variable: model_challenger     Importance: 0.0
# Variable: model_challenger sxt plus coupe Importance: 0.0
# Variable: model_charger r/t daytona Importance: 0.0
# Variable: model_charger se     Importance: 0.0
# Variable: model_cherokee latitude Importance: 0.0
# Variable: model_cherokee sport 4x4 suv Importance: 0.0
# Variable: model_cherokee sport xj Importance: 0.0
# Variable: model_cheyenne 2500  Importance: 0.0
# Variable: model_ci             Importance: 0.0
# Variable: model_civic          Importance: 0.0
# Variable: model_civic ex       Importance: 0.0
# Variable: model_civic ex coupe Importance: 0.0
# Variable: model_civic hybrid   Importance: 0.0
# Variable: model_civic lx sedan 4dr Importance: 0.0
# Variable: model_civic lx,      Importance: 0.0
# Variable: model_cj7 4x4        Importance: 0.0
# Variable: model_classic        Importance: 0.0
# Variable: model_clk 350        Importance: 0.0
# Variable: model_club wagon     Importance: 0.0
# Variable: model_cobalt         Importance: 0.0
# Variable: model_cobalt ls      Importance: 0.0
# Variable: model_colorado       Importance: 0.0
# Variable: model_colorado 4x4   Importance: 0.0
# Variable: model_colorado crew cab z71 Importance: 0.0
# Variable: model_colorado z71   Importance: 0.0
# Variable: model_commander      Importance: 0.0
# Variable: model_compass fwd 4dr sport Importance: 0.0
# Variable: model_compass latitude Importance: 0.0
# Variable: model_compass limited Importance: 0.0
# Variable: model_compass sport se Importance: 0.0
# Variable: model_continental town car Importance: 0.0
# Variable: model_conversion van Importance: 0.0
# Variable: model_cooper countryman Importance: 0.0
# Variable: model_cooper s       Importance: 0.0
# Variable: model_cooper s clubman Importance: 0.0
# Variable: model_cordoba ls     Importance: 0.0
# Variable: model_corolla        Importance: 0.0
# Variable: model_corolla ce sedan Importance: 0.0
# Variable: model_corolla le 4dr sedan Importance: 0.0
# Variable: model_corolla le corolla Importance: 0.0
# Variable: model_corolla le premium Importance: 0.0
# Variable: model_corolla se     Importance: 0.0
# Variable: model_corvette coupe Importance: 0.0
# Variable: model_cr-4           Importance: 0.0
# Variable: model_cr-v           Importance: 0.0
# Variable: model_cr-v ex        Importance: 0.0
# Variable: model_cr-v lx awd    Importance: 0.0
# Variable: model_crossfire      Importance: 0.0
# Variable: model_crosstrek 2.0i premium Importance: 0.0
# Variable: model_crown victoria Importance: 0.0
# Variable: model_crown victoria police k9 Importance: 0.0
# Variable: model_cruze ls sedan 4d Importance: 0.0
# Variable: model_cruze lt diesel Importance: 0.0
# Variable: model_cruze lt rs    Importance: 0.0
# Variable: model_cruze ltz rs   Importance: 0.0
# Variable: model_crv ex         Importance: 0.0
# Variable: model_crv exl        Importance: 0.0
# Variable: model_cts 3.6l performance Importance: 0.0
# Variable: model_cube           Importance: 0.0
# Variable: model_cummins 3500   Importance: 0.0
# Variable: model_custom         Importance: 0.0
# Variable: model_cx-7           Importance: 0.0
# Variable: model_cx9 grand touring Importance: 0.0
# Variable: model_dakota 4x4     Importance: 0.0
# Variable: model_dakota big horn Importance: 0.0
# Variable: model_dakota club cab slt 4wd Importance: 0.0
# Variable: model_dakota crew cab Importance: 0.0
# Variable: model_dakota ext cab Importance: 0.0
# Variable: model_dakota slt     Importance: 0.0
# Variable: model_dakota slt 4x4 Importance: 0.0
# Variable: model_dart           Importance: 0.0
# Variable: model_dart limited   Importance: 0.0
# Variable: model_dart rallye    Importance: 0.0
# Variable: model_dart se        Importance: 0.0
# Variable: model_deisel cummins 3500 Importance: 0.0
# Variable: model_deville        Importance: 0.0
# Variable: model_diesel cummins 2500 Importance: 0.0
# Variable: model_discovery      Importance: 0.0
# Variable: model_durango crew   Importance: 0.0
# Variable: model_durango limited rwd Importance: 0.0
# Variable: model_durango slt    Importance: 0.0
# Variable: model_dynamite       Importance: 0.0
# Variable: model_e 150 xl       Importance: 0.0
# Variable: model_e 350 4matic   Importance: 0.0
# Variable: model_e-350          Importance: 0.0
# Variable: model_e-series cargo e-350 e350 s Importance: 0.0
# Variable: model_e150           Importance: 0.0
# Variable: model_e250 cargo van Importance: 0.0
# Variable: model_e250 econoline Importance: 0.0
# Variable: model_e350           Importance: 0.0
# Variable: model_e350 passenger van Importance: 0.0
# Variable: model_e350 super duty cargo Importance: 0.0
# Variable: model_e350 van       Importance: 0.0
# Variable: model_eclipse        Importance: 0.0
# Variable: model_econoline e350 Importance: 0.0
# Variable: model_econoline wagon Importance: 0.0
# Variable: model_edge limited   Importance: 0.0
# Variable: model_edge se        Importance: 0.0
# Variable: model_edge sel fwd   Importance: 0.0
# Variable: model_edge sport     Importance: 0.0
# Variable: model_el camino      Importance: 0.0
# Variable: model_elantra gls    Importance: 0.0
# Variable: model_elantra limited sedan 4d Importance: 0.0
# Variable: model_elantra se     Importance: 0.0
# Variable: model_eldorado       Importance: 0.0
# Variable: model_enclave 4dr leather Importance: 0.0
# Variable: model_enclave cxl    Importance: 0.0
# Variable: model_encore         Importance: 0.0
# Variable: model_endeavor ls    Importance: 0.0
# Variable: model_entourage gls minivan Importance: 0.0
# Variable: model_envoy          Importance: 0.0
# Variable: model_equinox ls     Importance: 0.0
# Variable: model_es 350         Importance: 0.0
# Variable: model_es330          Importance: 0.0
# Variable: model_es350          Importance: 0.0
# Variable: model_es350 2017     Importance: 0.0
# Variable: model_escape limited Importance: 0.0
# Variable: model_escape s       Importance: 0.0
# Variable: model_escape sel fwd Importance: 0.0
# Variable: model_escort         Importance: 0.0
# Variable: model_ex35           Importance: 0.0
# Variable: model_excursion      Importance: 0.0
# Variable: model_excursion eddie bauer Importance: 0.0
# Variable: model_excursion xlt  Importance: 0.0
# Variable: model_expedition el  Importance: 0.0
# Variable: model_expedition limited Importance: 0.0
# Variable: model_expedition xlt Importance: 0.0
# Variable: model_expedition xlt 4x4 Importance: 0.0
# Variable: model_expedtion xlt  Importance: 0.0
# Variable: model_explorer awd   Importance: 0.0
# Variable: model_explorer limited Importance: 0.0
# Variable: model_explorer limited 4x4 Importance: 0.0
# Variable: model_explorer sport Importance: 0.0
# Variable: model_explorer sport trac Importance: 0.0
# Variable: model_explorer utility sport trac Importance: 0.0
# Variable: model_explorer xlt   Importance: 0.0
# Variable: model_express 2500 v8 Importance: 0.0
# Variable: model_express 3500   Importance: 0.0
# Variable: model_express 3500 cargo van Importance: 0.0
# Variable: model_express 3500 van Importance: 0.0
# Variable: model_express cargo van Importance: 0.0
# Variable: model_express g2500 cargo van Importance: 0.0
# Variable: model_express g3500  Importance: 0.0
# Variable: model_express passenger Importance: 0.0
# Variable: model_f 150          Importance: 0.0
# Variable: model_f 150 xlt      Importance: 0.0
# Variable: model_f 150 xlt 4x4  Importance: 0.0
# Variable: model_f-150 lariat   Importance: 0.0
# Variable: model_f-150 platinum Importance: 0.0
# Variable: model_f-150 supercrew 4x4 Importance: 0.0
# Variable: model_f-150 sxt      Importance: 0.0
# Variable: model_f-150 xl       Importance: 0.0
# Variable: model_f-150 xl 4x4   Importance: 0.0
# Variable: model_f-150 xlt      Importance: 0.0
# Variable: model_f-150 xlt supercab Importance: 0.0
# Variable: model_f-150 xlt supercab 4x4 Importance: 0.0
# Variable: model_f-250 460 7.5 liter Importance: 0.0
# Variable: model_f-250 4x4      Importance: 0.0
# Variable: model_f-250 lariat super duty Importance: 0.0
# Variable: model_f-250 super duty xlt Importance: 0.0
# Variable: model_f-250sd        Importance: 0.0
# Variable: model_f-250sd xlt    Importance: 0.0
# Variable: model_f-350          Importance: 0.0
# Variable: model_f-350 4x4 crewcab Importance: 0.0
# Variable: model_f-350 bulletproofed diesel rust free tx truck Importance: 0.0
# Variable: model_f-350 super duty Importance: 0.0
# Variable: model_f-350 super duty lariat Importance: 0.0
# Variable: model_f-350 xlt      Importance: 0.0
# Variable: model_f-350 xlt 4x4 v-10 Importance: 0.0
# Variable: model_f-450 super duty Importance: 0.0
# Variable: model_f-550 4x2      Importance: 0.0
# Variable: model_f-650          Importance: 0.0
# Variable: model_f100           Importance: 0.0
# Variable: model_f150 ext 2wd v8 Importance: 0.0
# Variable: model_f150 lariat    Importance: 0.0
# Variable: model_f150 lariat 4wd Importance: 0.0
# Variable: model_f150 lariat supercrew 4x4 Importance: 0.0
# Variable: model_f150 platinum  Importance: 0.0
# Variable: model_f150 platinum 4wd Importance: 0.0
# Variable: model_f150 super crew cab Importance: 0.0
# Variable: model_f150 supercab  Importance: 0.0
# Variable: model_f150 supercab fx4 Importance: 0.0
# Variable: model_f150 supercab fx4 pickup Importance: 0.0
# Variable: model_f150 supercrew Importance: 0.0
# Variable: model_f150 supercrew 4x4 Importance: 0.0
# Variable: model_f150 supercrew cab xlt Importance: 0.0
# Variable: model_f150 supercrew king ranch Importance: 0.0
# Variable: model_f150 xl        Importance: 0.0
# Variable: model_f150 xlt 4x4   Importance: 0.0
# ...
# Variable: model_sienna xle awd Importance: 0.0
# Variable: model_sierra 1500 extended cab Importance: 0.0
# Variable: model_sierra 1500 sle Importance: 0.0
# Variable: model_sierra 1500 sle double cab Importance: 0.0
# Variable: model_sierra 1500 slt 4wd truck l Importance: 0.0
# Variable: model_sierra 2500 denali hd 4x4 Importance: 0.0
# Variable: model_sierra 2500hd 4wd z-71 Importance: 0.0
# Variable: model_sierra 3500hd denali Importance: 0.0
# Variable: model_sierra grande  Importance: 0.0
# Variable: model_sierra sle     Importance: 0.0
# Variable: model_sierra z71     Importance: 0.0
# Variable: model_silvarado 2500 Importance: 0.0
# Variable: model_silvera        Importance: 0.0
# Variable: model_silverado 1500 crew cab Importance: 0.0
# Variable: model_silverado 1500 ld Importance: 0.0
# Variable: model_silverado 1500 lt 4x4 Importance: 0.0
# Variable: model_silverado 1500 lt x-c Importance: 0.0
# Variable: model_silverado 1500 ltz short bed lifted loaded Importance: 0.0
# Variable: model_silverado 1500. wt Importance: 0.0
# Variable: model_silverado 2500 hd Importance: 0.0
# Variable: model_silverado 2500hd 4wd rust free tx truck Importance: 0.0
# Variable: model_silverado 2500hd duramax Importance: 0.0
# Variable: model_silverado 3500 Importance: 0.0
# Variable: model_silverado 3500hd Importance: 0.0
# Variable: model_silverado 3500hd 4x4 Importance: 0.0
# Variable: model_silverado k1500 Importance: 0.0
# Variable: model_silverado ls 1500 Importance: 0.0
# Variable: model_silverado reg cab Importance: 0.0
# Variable: model_silverado rst  Importance: 0.0
# Variable: model_silverado z71  Importance: 0.0
# Variable: model_sky red line   Importance: 0.0
# Variable: model_solara sport conv Importance: 0.0
# Variable: model_sonata         Importance: 0.0
# Variable: model_sonata gls     Importance: 0.0
# Variable: model_sonata limited Importance: 0.0
# Variable: model_sonata se      Importance: 0.0
# Variable: model_sonata turbo 2.0 Importance: 0.0
# Variable: model_sonic          Importance: 0.0
# Variable: model_sonic lt       Importance: 0.0
# Variable: model_sonic lt auto  Importance: 0.0
# Variable: model_sonoma sls ext cab Importance: 0.0
# Variable: model_sorento        Importance: 0.0
# Variable: model_sorento awd    Importance: 0.0
# Variable: model_sorento lx     Importance: 0.0
# Variable: model_sorrento       Importance: 0.0
# Variable: model_soul +         Importance: 0.0
# Variable: model_soul base      Importance: 0.0
# Variable: model_spectra ex sedan Importance: 0.0
# Variable: model_sport          Importance: 0.0
# Variable: model_sport trac xlt Importance: 0.0
# Variable: model_sportage       Importance: 0.0
# Variable: model_sportage awd   Importance: 0.0
# Variable: model_sportage lx    Importance: 0.0
# Variable: model_sportage lx awd Importance: 0.0
# Variable: model_sprinter cargo vans Importance: 0.0
# Variable: model_srt10 viper    Importance: 0.0
# Variable: model_srx            Importance: 0.0
# Variable: model_srx luxury     Importance: 0.0
# Variable: model_stealth r/t    Importance: 0.0
# Variable: model_suburban 2500  Importance: 0.0
# Variable: model_suburban lt    Importance: 0.0
# Variable: model_suburban ltz   Importance: 0.0
# Variable: model_suburban z71   Importance: 0.0
# Variable: model_super duty f-250 king ranch Importance: 0.0
# Variable: model_superchar      Importance: 0.0
# Variable: model_sw1 station wagon Importance: 0.0
# Variable: model_t-250          Importance: 0.0
# Variable: model_tacoma double cab sr5 Importance: 0.0
# Variable: model_tacoma trd sport Importance: 0.0
# Variable: model_tahoe ls       Importance: 0.0
# Variable: model_tahoe ltz      Importance: 0.0
# Variable: model_taurus sel     Importance: 0.0
# Variable: model_taurus ses     Importance: 0.0
# Variable: model_terrain awd slt Importance: 0.0
# Variable: model_terrain denali awd Importance: 0.0
# Variable: model_terrain denali awd v6 Importance: 0.0
# Variable: model_terrain sle-1  Importance: 0.0
# Variable: model_terrain slt all wheel drive Importance: 0.0
# Variable: model_thunderbird    Importance: 0.0
# Variable: model_tiguan 2.0t wolfsburg Importance: 0.0
# Variable: model_tiguan sel     Importance: 0.0
# Variable: model_titan crew cab Importance: 0.0
# Variable: model_titan le 4x4   Importance: 0.0
# Variable: model_tl navigation  Importance: 0.0
# Variable: model_tl type s      Importance: 0.0
# Variable: model_tlx 3.5l v6    Importance: 0.0
# Variable: model_topkick        Importance: 0.0
# Variable: model_touareg        Importance: 0.0
# Variable: model_touareg tdi    Importance: 0.0
# Variable: model_town           Importance: 0.0
# Variable: model_town & country touring Importance: 0.0
# Variable: model_town country   Importance: 0.0
# Variable: model_town country touring l Importance: 0.0
# Variable: model_towncar        Importance: 0.0
# Variable: model_towncar ultimate Importance: 0.0
# Variable: model_trail blazer   Importance: 0.0
# Variable: model_trail blazer 4x4 Importance: 0.0
# Variable: model_trailblazer 4wd ext lt Importance: 0.0
# Variable: model_transit        Importance: 0.0
# Variable: model_transit cargo  Importance: 0.0
# Variable: model_transit connect Importance: 0.0
# Variable: model_transit connect wagon Importance: 0.0
# Variable: model_transit connect xlt premium Importance: 0.0
# Variable: model_transit t150 cargo van Importance: 0.0
# Variable: model_transit t150 xlt van Importance: 0.0
# Variable: model_transit t250 cargo van Importance: 0.0
# Variable: model_traverse awd   Importance: 0.0
# Variable: model_traverse ls    Importance: 0.0
# Variable: model_traverse lt awd Importance: 0.0
# Variable: model_trax lt        Importance: 0.0
# Variable: model_tribeca awd    Importance: 0.0
# Variable: model_truck          Importance: 0.0
# Variable: model_tuarus         Importance: 0.0
# Variable: model_tucson se      Importance: 0.0
# Variable: model_tundra 4wd     Importance: 0.0
# Variable: model_tundra 4wd truck Importance: 0.0
# Variable: model_tundra access cab sr5 Importance: 0.0
# Variable: model_tundra crewmax 4x4 5.7l Importance: 0.0
# Variable: model_tundra double cab sr5 Importance: 0.0
# Variable: model_tundra limited access cab Importance: 0.0
# Variable: model_tundra sr5     Importance: 0.0
# Variable: model_tundra sr5 access cab Importance: 0.0
# Variable: model_tundra sr5 double cab 4x4 Importance: 0.0
# Variable: model_tundra sr5 extended cab Importance: 0.0
# Variable: model_tundra v8 4x4  Importance: 0.0
# Variable: model_tuscon awd     Importance: 0.0
# Variable: model_uplander       Importance: 0.0
# Variable: model_v50            Importance: 0.0
# Variable: model_v70            Importance: 0.0
# Variable: model_veloster       Importance: 0.0
# Variable: model_veloster turbo Importance: 0.0
# Variable: model_venza          Importance: 0.0
# Variable: model_verano leather group Importance: 0.0
# Variable: model_versa hatchback Importance: 0.0
# Variable: model_versa s        Importance: 0.0
# Variable: model_versa sl hatchback Importance: 0.0
# Variable: model_versa sv       Importance: 0.0
# Variable: model_versa sv sedan Importance: 0.0
# Variable: model_volt premier   Importance: 0.0
# Variable: model_volt premium   Importance: 0.0
# Variable: model_vue xr         Importance: 0.0
# Variable: model_wrangler 4wd 2dr sport Importance: 0.0
# Variable: model_wrangler 5 spd Importance: 0.0
# Variable: model_wrangler lwb   Importance: 0.0
# Variable: model_wrangler sahara Importance: 0.0
# Variable: model_wrangler sahara 4x4 Importance: 0.0
# Variable: model_wrangler tj sahara Importance: 0.0
# Variable: model_wrangler unlimited sport Importance: 0.0
# Variable: model_wrangler x     Importance: 0.0
# Variable: model_wrangler yj    Importance: 0.0
# Variable: model_wrx            Importance: 0.0
# Variable: model_x1 xdrive35i   Importance: 0.0
# Variable: model_x3             Importance: 0.0
# Variable: model_x3 3.0         Importance: 0.0
# Variable: model_x3 3.0si       Importance: 0.0
# Variable: model_x3 35i         Importance: 0.0
# Variable: model_x3 awd         Importance: 0.0
# Variable: model_x5 3.0i        Importance: 0.0
# Variable: model_x5 30i xdrive  Importance: 0.0
# Variable: model_x5 premium awd suv Importance: 0.0
# Variable: model_x6             Importance: 0.0
# Variable: model_xc 60 awd one owner Importance: 0.0
# Variable: model_xc60           Importance: 0.0
# Variable: model_xc70 all wheel drive Importance: 0.0
# Variable: model_xc90           Importance: 0.0
# Variable: model_xjl            Importance: 0.0
# Variable: model_xk8            Importance: 0.0
# Variable: model_xts luxury     Importance: 0.0
# Variable: model_yukon dinali xl Importance: 0.0
# Variable: model_yukon slt      Importance: 0.0
# Variable: model_yukon xl 3/4 ton 4x4 Importance: 0.0
# Variable: model_yukon xl sle 1500 Importance: 0.0
# Variable: model_yukon xl slt 1500 Importance: 0.0
# Variable: model_z3             Importance: 0.0
# Variable: condition_salvage    Importance: 0.0
# Variable: cylinders_other      Importance: 0.0
# Variable: fuel_electric        Importance: 0.0
# Variable: transmission_other   Importance: 0.0
# Variable: state_hi             Importance: 0.0
# Variable: state_wv             Importance: 0.0
# Variable: state_wy             Importance: 0.0
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
rf_feature_importances_top20 = sorted_feats_rf_score[:20]
featureNames, featureScores = zip(*list(rf_feature_importances_top20))

plt.barh(range(len(featureScores)), featureScores, tick_label=featureNames)
plt.gca().invert_yaxis()
plt.title('feature importance')
plt.ylabel('Features')
plt.xlabel('Importance Score')
plt.title('Feature Importances')
# Out:
# Text(0.5, 1.0, 'Feature Importances')

# %%
rf_feature_importances_top20
# Out:
# [('year', 0.42436),
#  ('odometer_log', 0.13374),
#  ('drive_fwd', 0.12693),
#  ('fuel_gas', 0.04298),
#  ('cylinders_8 cylinders', 0.02892),
#  ('cylinders_4 cylinders', 0.01797),
#  ('condition_fair', 0.00883),
#  ('condition_good', 0.00848),
#  ('type_truck', 0.00802),
#  ('type_sedan', 0.0072),
#  ('cylinders_6 cylinders', 0.00694),
#  ('model_durango', 0.00473),
#  ('paint_color_white', 0.00441),
#  ('model_535i', 0.00419),
#  ('state_in', 0.00368),
#  ('size_mid-size', 0.00366),
#  ('transmission_manual', 0.00341),
#  ('drive_rwd', 0.00315),
#  ('state_nh', 0.00306),
#  ('manufacturer_ram', 0.00296)]

# %%
grid_rforest = grid_search_rforest.best_estimator_
feature_importance = 100.0 * (grid_rforest.feature_importances_ / grid_rforest.feature_importances_.max())
important_features = X_train.columns[feature_importance >= 0.05]
unimportant_features = X_train.columns[feature_importance < 0.05]

# %%
X_train_reduced = X_train.drop(unimportant_features, axis=1)
X_test_reduced = X_test.drop(unimportant_features, axis=1)

# %% [markdown]
# #### Random Forest grid search with important features

# %%
rForest_feats = RandomForestRegressor()

param_grid ={'max_depth': [10, 20, 30, 40, 50],
             'max_features': ['auto','sqrt','log2'],
             'min_samples_split':[2,3,4],
             'n_estimators': [100, 300, 500, 800]}

rForest_feats.set_params(random_state=42)

grid_search_rForest2 = ms.GridSearchCV(rForest_feats, param_grid, scoring= 'neg_mean_squared_error',
                           cv= kfo, n_jobs = -1, return_train_score=True, verbose = 1)
grid_search_rForest2.fit(X_train_reduced, y_train)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 900 out of 900 | elapsed: 11.4min finished
# GridSearchCV(cv=KFold(n_splits=5, random_state=28, shuffle=True),
#              error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_es...ors=100, n_jobs=None,
#                                              oob_score=False, random_state=42,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'max_depth': [10, 20, 30, 40, 50],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [100, 300, 500, 800]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=1)

# %%
# get the best parameters
grid_search_rForest2.best_params_
# Out:
# {'max_depth': 30,
#  'max_features': 'auto',
#  'min_samples_split': 2,
#  'n_estimators': 800}

# %%
predictions_tuned_rForest2 = grid_search_rForest2.best_estimator_.predict(X_test_reduced)

# Calculate the absolute errors
errors = abs(np.expm1(predictions_tuned_rForest2) - np.expm1(y_test))

# Print out the mean absolute error (MAE)
print('Mean Absolute Error (MAE): $', round(np.mean(errors), 2))
print('MSE:', mean_squared_error(y_test, predictions_tuned_rForest2))
print('RMSE:', np.sqrt(mean_squared_error(y_test, predictions_tuned_rForest2)))

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / np.expm1(y_test))

# Calculate and display MAPE
#accuracy = 100 - np.mean(mape)
print('MAPE:', round(np.mean(mape), 2), '%.')
# Out:
# Mean Absolute Error (MAE): $ 2720.26
# MSE: 0.1576031443969546
# RMSE: 0.3969926251165815
# MAPE: 33.98 %.

# %% [markdown]
# ##### Results

# %%
info = [['Random Forest',mean_squared_error(y_test,rforest_pred),(rforest.score(X_test_scaled,y_test))],
        ['Random Forest Grid Search 1',mean_squared_error(y_test,grid_rforest_pred),grid_rforest.score(X_test_scaled, y_test)],
       ['Random Forest Grid Search Impt.Feat',mean_squared_error(y_test, predictions_tuned_rForest2),grid_search_rForest2.score(X_test_reduced, y_test)]]
rf_info = pd.DataFrame(info, columns= ['Name','MSE','R2-Score']) 
rf_info
# Out:
#                                   Name       MSE  R2-Score
# 0                        Random Forest  0.175511  0.696128
# 1          Random Forest Grid Search 1  0.158430  0.725702
# 2  Random Forest Grid Search Impt.Feat  0.157603 -0.157603

# %% [markdown]
# ##### Stacking Model with all used models (Lasso, Elastic, XG Boost, Random Forest)

# %%
stackMod = StackingCVRegressor(regressors=(grid_lasso,grid_eNet,grid_xgb1,grid_rforest),
                              meta_regressor = grid_xgb, shuffle = True,
                              random_state = 20,
                              use_features_in_secondary= True)
# %time stackMod.fit(X_train_scaled,y_train)
# Out:
# Wall time: 6min 57s
# StackingCVRegressor(cv=5,
#                     meta_regressor=XGBRegressor(base_score=0.5,
#                                                 booster='gbtree',
#                                                 colsample_bylevel=1,
#                                                 colsample_bynode=1,
#                                                 colsample_bytree=1, gamma=0,
#                                                 importance_type='gain',
#                                                 learning_rate=0.05,
#                                                 max_delta_step=0, max_depth=3,
#                                                 min_child_weight=4,
#                                                 missing=None, n_estimators=500,
#                                                 n_jobs=1, nthread=None,
#                                                 objective='reg:squarederror',
#                                                 random_state=22, reg_alpha=0,...
#                                                       max_features='auto',
#                                                       max_leaf_nodes=None,
#                                                       max_samples=None,
#                                                       min_impurity_decrease=0.0,
#                                                       min_impurity_split=None,
#                                                       min_samples_leaf=1,
#                                                       min_samples_split=2,
#                                                       min_weight_fraction_leaf=0.0,
#                                                       n_estimators=500,
#                                                       n_jobs=None,
#                                                       oob_score=False,
#                                                       random_state=52,
#                                                       verbose=0,
#                                                       warm_start=False)),
#                     shuffle=True, store_train_meta_features=False,
#                     use_features_in_secondary=True, verbose=0)

# %%
print("Train R^2: %.5f" % stackMod.score(np.array(X_train_scaled), np.array(y_train)))
print("Test R^2: %.5f" % stackMod.score(np.array(X_test_scaled), np.array(y_test)))
# Out:
# Train R^2: 0.88179
# Test R^2: 0.75894

# %%
# Initial prediction
stackMod_pred = stackMod.predict(np.array(X_test_scaled))
printErrors(y_test, stackMod_pred)
# Out:
# Mean Absolute Error (MAE): $ 2605.39
# Mean Squared Error (MSE): 0.13922925673725778
# Root Mean Square Error (RMSE): 0.3731343682070278
# Root Mean Square Log Error (RMSLE): 0.038326027553563374
# Mean Absolute Percent Error (MAPE): 30.29 %.

# %%
info = [['Stacking',mean_squared_error(y_test,stackMod_pred),stackMod.score(np.array(X_test_scaled),np.array(y_test))]]
stack_info = pd.DataFrame(info, columns= ['Name','MSE','R2-Score']) 
stack_info
# Out:
#        Name       MSE  R2-Score
# 0  Stacking  0.139229  0.758944

# %% [markdown]
# ##### Stacking model without Elastic Net (highest MSE)

# %%
stackModModwoElas = StackingCVRegressor(regressors=(grid_lasso,grid_xgb1,grid_rforest),
                              meta_regressor = grid_xgb, shuffle = True,
                              random_state = 20,
                              use_features_in_secondary= True)
# %time stackModModwoElas.fit(np.array(X_train_scaled),np.array(y_train))
# Out:
# Wall time: 6min 27s
# StackingCVRegressor(cv=5,
#                     meta_regressor=XGBRegressor(base_score=0.5,
#                                                 booster='gbtree',
#                                                 colsample_bylevel=1,
#                                                 colsample_bynode=1,
#                                                 colsample_bytree=1, gamma=0,
#                                                 importance_type='gain',
#                                                 learning_rate=0.05,
#                                                 max_delta_step=0, max_depth=3,
#                                                 min_child_weight=4,
#                                                 missing=None, n_estimators=500,
#                                                 n_jobs=1, nthread=None,
#                                                 objective='reg:squarederror',
#                                                 random_state=22, reg_alpha=0,...
#                                                       max_features='auto',
#                                                       max_leaf_nodes=None,
#                                                       max_samples=None,
#                                                       min_impurity_decrease=0.0,
#                                                       min_impurity_split=None,
#                                                       min_samples_leaf=1,
#                                                       min_samples_split=2,
#                                                       min_weight_fraction_leaf=0.0,
#                                                       n_estimators=500,
#                                                       n_jobs=None,
#                                                       oob_score=False,
#                                                       random_state=52,
#                                                       verbose=0,
#                                                       warm_start=False)),
#                     shuffle=True, store_train_meta_features=False,
#                     use_features_in_secondary=True, verbose=0)

# %%
print("Train R^2: %.5f" % stackModModwoElas.score(np.array(X_train_scaled), np.array(y_train)))
print("Test R^2: %.5f" % stackModModwoElas.score(np.array(X_test_scaled), np.array(y_test)))
# Out:
# Train R^2: 0.88446
# Test R^2: 0.75872

# %%
# Initial prediction
stackModwoElas_pred = stackModModwoElas.predict(np.array(X_test_scaled))
printErrors(y_test, stackModwoElas_pred)
# Out:
# Mean Absolute Error (MAE): $ 2610.14
# Mean Squared Error (MSE): 0.13935772877923683
# Root Mean Square Error (RMSE): 0.3733064810303149
# Root Mean Square Log Error (RMSLE): 0.03831566245695953
# Mean Absolute Percent Error (MAPE): 30.3 %.

# %%
info = [['Stacking_no_eNet',mean_squared_error(y_test,stackModwoElas_pred),stackModModwoElas.score(np.array(X_test_scaled),np.array(y_test))]]
stack2_info = pd.DataFrame(info, columns= ['Name','MSE','R2-Score']) 
stack2_info
# Out:
#                Name       MSE  R2-Score
# 0  Stacking_no_eNet  0.139358  0.758722

# %%
# Results
results = [lasso_info,eNet_info,xgb_info,rf_info,stack_info,stack2_info]
result = pd.concat(results,ignore_index=True)
models = result.sort_values(by = 'MSE')
models
# Out:
#                                    Name       MSE  R2-Score
# 6                 XGBoost Grid Search 2  0.138333  0.760497
# 5                 XGBoost Grid Search 1  0.139143  0.759094
# 11                             Stacking  0.139229  0.758944
# 12                     Stacking_no_eNet  0.139358  0.758722
# 7        XG Boost Grid Search Impt.Feat  0.143349 -0.143349
# 4                               XGBoost  0.149584  0.741017
# 10  Random Forest Grid Search Impt.Feat  0.157603 -0.157603
# 9           Random Forest Grid Search 1  0.158430  0.725702
# 8                         Random Forest  0.175511  0.696128
# 3               Elastic Net Grid Search  0.198696  0.655986
# 1                     Lasso Grid Search  0.202751  0.648965
# 0                                 Lasso  0.577823 -0.000418
# 2                           Elastic Net  0.577823 -0.000418

# %% [markdown]
# ### Final Model Selection
# ###### Overall, the XGBoost model is the preferred model, which performs better than the Random Forest and just as good as the Stacking model. It could possibly be improved further with hyper-parameter tuning. Thus, XGBoost was able to predict 76% of the variation of car sale prices.
